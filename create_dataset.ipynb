# %%
# csv format
columns = ["kural_number", "kural_in_tamil", "meaning_in_tamil", "kural_in_english", "meaning_in_english", "category", "tags", "q1", "q2", "q3"]
import pandas as pd

df = pd.DataFrame(columns=columns)
df
# Out:
# Empty DataFrame
# Columns: [kural_number, kural_in_tamil, meaning_in_tamil, kural_in_english, meaning_in_english, category, tags, q1, q2, q3]
# Index: []

# %%
tamil_vs_eng_url = "https://www.projectmadurai.org/pm_etexts/utf8/pmuni0017.html"

tamil_meaning = ["https://www.projectmadurai.org/pm_etexts/utf8/pmuni0450_01.html", "https://www.projectmadurai.org/pm_etexts/utf8/pmuni0450_02.html", "https://www.projectmadurai.org/pm_etexts/utf8/pmuni0450_03.html", "https://www.projectmadurai.org/pm_etexts/utf8/pmuni0450_04.html"]

tamil_vs_eng_url_html = "tamil_vs_eng_url.html"

# %%
import os
from bs4 import BeautifulSoup

if not os.path.exists(tamil_vs_eng_url_html):
	# !wget -O {tamil_vs_eng_url_html} {tamil_vs_eng_url}

with open(tamil_vs_eng_url_html, "r", encoding="utf-8") as file:
    html_content = file.read()

soup = BeautifulSoup(html_content, "html5lib")
with open(tamil_vs_eng_url_html, "w", encoding="utf-8") as file:
    file.write(soup.prettify())

print("HTML fetched and saved successfully!")
# Out:
# HTML fetched and saved successfully!

# %%
import re
import json
all_text = [tag.get_text(strip=True) for tag in soup.find_all("center")]
main_topic = []
temp_dup = set()
for i in range(1, 1330):
	for content in all_text:
		if "Part " in content:
			if content not in temp_dup:
				temp_dup.add(content)
				split_text = re.split(r"- Part .* -", content)
				main_topic.append({
					"main_topic": {
						"tamil": split_text[0].split(".")[-1].strip(),
						"english": split_text[-1].strip()
					}
				})

print(json.dumps(main_topic, indent=4, ensure_ascii=False))
# Out:
# [
#     {
#         "main_topic": {
#             "tamil": "அறத்துப்பால்",
#             "english": "VIRTUE"
#         }
#     },
#     {
#         "main_topic": {
#             "tamil": "பொருட்பால்",
#             "english": "WEALTH"
#         }
#     },
#     {
#         "main_topic": {
#             "tamil": "இன்பத்துப்பால்",
#             "english": "NATURE OF LOVE"
#         }
#     }
# ]

# %%
def remove_leading_number(text):
	# Remove leading patterns like "1.1", "1.2", etc.
	text = re.sub(r"^\s*\d+\.\d+\s*", "", text)
	# Remove leading patterns like "1.", "2.", etc.
	text = re.sub(r"^\s*\d+\.\s*", "", text)
	# Remove leading patterns like "1", "2", etc.
	text = re.sub(r"^\s*\d+\s*", "", text)
	# Remove trailing numbers
	text = re.sub(r"\s*\d+$", "", text)
	# Replace multiple spaces with single space
	text = re.sub(r"\s+", " ", text)
	return text.strip()

def clean_text(text):
	"""Remove multiple spaces, replace newlines with spaces, and trim start & end spaces."""
	text = re.sub(r"\s+", " ", text)  # Replace multiple spaces & newlines with single space
	return text.strip()  # Remove spaces from start & end

# %%
all_ul_tags = soup.find_all("ul")
for tag in all_ul_tags:
	prev_elem = tag.previous_element
	while remove_leading_number(prev_elem.get_text()) == "":
		prev_elem = prev_elem.previous_element

	index = int(prev_elem.get_text().strip()[0]) - 1
	sub_topic = remove_leading_number(prev_elem.get_text())
	if "sub_topic" not in main_topic[index]:
		main_topic[index]["sub_topic"] = []
	
	parts = sub_topic.split("-", 1)
	main_topic[index]["sub_topic"].append({
		"tamil": remove_leading_number(parts[0]),
		"english": remove_leading_number(parts[1])
	})
	main_topic[index]["sub_topic"][-1]["category"] = []
	for row in tag.find_all("tr"):
		columns = row.find_all("td")
		if len(columns) >= 2:
			if "category" not in main_topic[index]["sub_topic"][-1]:
				main_topic[index]["sub_topic"][-1]["category"] = []

			main_topic[index]["sub_topic"][-1]["category"].append({
				"tamil": remove_leading_number(columns[0].get_text()),
				"english": remove_leading_number(columns[1].get_text()),
				"kurals": []
			})

print(json.dumps(main_topic, indent=4, ensure_ascii=False))
# Out:
# [
#     {
#         "main_topic": {
#             "tamil": "அறத்துப்பால்",
#             "english": "VIRTUE"
#         },
#         "sub_topic": [
#             {
#                 "tamil": "பாயிரம்",
#                 "english": "PREFACE",
#                 "category": [
#                     {
#                         "tamil": "கடவுள் வாழ்த்து",
#                         "english": "The praise of God",
#                         "kurals": []
#                     },
#                     {
#                         "tamil": "வான் சிறப்பு",
#                         "english": "The blessing of Rain",
#                         "kurals": []
#                     },
#                     {
#                         "tamil": "நீத்தார் பெருமை",
#                         "english": "The merit of Ascetics",
#                         "kurals": []
#                     },
#                     {
#                         "tamil": "அறன் வலியுறுத்தல்",
#                         "english": "The power of virtue",
#                         "kurals": []
#                     }
#                 ]
#             },
#             {
#                 "tamil": "இல்லறவியல்",
#                 "english": "DOMESTIC VIRTUE",
#                 "category": [
#                     {
#                         "tamil": "இல்வாழ்க்கை",
#                         "english": "Married Life",
#                         "kurals": []
#                     },
#                     {
#                         "tamil": "வாழ்க்கைத் துணைநலம்",
#                         "english": "The worth of a wife",
#                         "kurals": []
#                     },
#                     {
#                         "tamil": "மக்கட்பேறு",
#                         "english": "The wealth of children",
#                         "kurals": []
#                     },
#                     {
#                         "tamil": "அன்புடைமை",
#                         "english": "Loving-kindness",
#                         "kurals": []
#                     },
#                     {
#                         "tamil": "விருந்தோம்பல்",
#                         "english": "Hospitality",
#                         "kurals": []
#                     },
#                     {
#                         "tamil": ". இனியவை கூறல்",
#                         "english": "Sweet words",
#                         "kurals": []
#                     },
#                     {
#                         "tamil": "செய்ந்நன்றி அறிதல்",
#                         "english": "Gratitude",
#                         "kurals": []
#                     },
#                     {
#                         "tamil": "நடுநிலைமை",
#                         "english": "Equity",
#                         "kurals": []
#                     },
#                     {
#                         "tamil": "அடக்கமுடைமை",
#                         "english": "Self-control",
#                         "kurals": []
#                     },
#                     {
#                         "tamil": "ஒழுக்கமுடைமை",
#                         "english": "Good decorum",
#                         "kurals": []
#                     },
#                     {
#                         "tamil": "பிறனில் விழையாமை",
#                         "english": "Against coveting another's wife",
#                         "kurals": []
#                     },
#                     {
#                         "tamil": "பொறையுடைமை",
#                         "english": "Forgiveness",
#                         "kurals": []
#                     },
#                     {
#                         "tamil": "அழுக்காறாமை",
#                         "english": "Avoid envy",
#                         "kurals": []
#                     },
#                     {
#                         "tamil": "வெஃகாமை",
#                         "english": "Against covetousness",
#                         "kurals": []
#                     },
#                     {
#                         "tamil": "புறங்கூறாமை",
#                         "english": "Against slander",
#                         "kurals": []
#                     },
#                     {
#                         "tamil": "பயனில சொல்லாமை",
#                         "english": "Against vain speaking",
#                         "kurals": []
#                     },
#                     {
#                         "tamil": "தீவினையச்சம்",
#                         "english": "Fear of sin",
#                         "kurals": []
#                     },
#                     {
#                         "tamil": "ஒப்புரவறிதல்",
#                         "english": "Duty to society",
#                         "kurals": []
#                     },
#                     {
#                         "tamil": "ஈகை",
#                         "english": "Charity",
#                         "kurals": []
#                     },
#                     {
#                         "tamil": "புகழ்",
#                         "english": "Renown",
#                         "kurals": []
#                     }
#                 ]
#             },
#             {
#                 "tamil": "துறவறவியல்",
#                 "english": "ASCETIC VIRTUE",
#                 "category": [
#                     {
#                         "tamil": "அருளுடைமை",
#                         "english": "Compassion",
#                         "kurals": []
#                     },
#                     {
#                         "tamil": "புலால்மறுத்தல்",
#                         "english": "Abstinence from flesh",
#                         "kurals": []
#                     },
#                     {
#                         "tamil": "தவம்",
#                         "english": "Penance",
#                         "kurals": []
#                     },
#                     {
#                         "tamil": "கூடாஒழுக்கம்",
#                         "english": "Imposture",
#                         "kurals": []
#                     },
#                     {
#                         "tamil": "கள்ளாமை",
#                         "english": "The absence of fraud",
#                         "kurals": []
#                     },
#                     {
#                         "tamil": "வாய்மை",
#                         "english": "Veracity",
#                         "kurals": []
#                     },
#                     {
#                         "tamil": "வெகுளாமை",
#                         "english": "Restraining anger",
#                         "kurals": []
#                     },
#                     {
#                         "tamil": "இன்னா செய்யாமை",
#                         "english": "non-violence",
#                         "kurals": []
#                     },
#                     {
#                         "tamil": "கொல்லாமை",
#                         "english": "Non-killing",
#                         "kurals": []
#                     },
#                     {
#                         "tamil": "நிலையாமை",
#                         "english": "Instability",
#                         "kurals": []
#                     },
#                     {
#                         "tamil": "துறவு",
#                         "english": "Renunciation",
#                         "kurals": []
#                     },
#                     {
#                         "tamil": "மெய்யுணர்தல்",
#                         "english": "Truth consciousness",
#                         "kurals": []
#                     },
#                     {
#                         "tamil": "அவா அறுத்தல்",
#                         "english": "Curbing of desire",
#                         "kurals": []
#                     },
#                     {
#                         "tamil": "ஊழ்.",
#                         "english": "Destiny",
#                         "kurals": []
#                     }
#                 ]
#             }
#         ]
#     },
#     {
#         "main_topic": {
#             "tamil": "பொருட்பால்",
#             "english": "WEALTH"
#         },
#         "sub_topic": [
#             {
#                 "tamil": "அரசியல்",
#                 "english": "Royalty",
#                 "category": [
#                     {
#                         "tamil": "இறைமாட்சி",
#                         "english": "The grandeur of monarchy",
#                         "kurals": []
#                     },
#                     {
#                         "tamil": "கல்வி",
#                         "english": "Education",
#                         "kurals": []
#                     },
#                     {
#                         "tamil": "கல்லாமை",
#                         "english": "Non- learning",
#                         "kurals": []
#                     },
#                     {
#                         "tamil": "கேள்வி",
#                         "english": "Listening",
#                         "kurals": []
#                     },
#                     {
#                         "tamil": "அறிவுடைமை",
#                         "english": "The possession of knowledge",
#                         "kurals": []
#                     },
#                     {
#                         "tamil": "குற்றங்கடிதல்",
#                         "english": "Avoiding faults",
#                         "kurals": []
#                     },
#                     {
#                         "tamil": "பெரியாரைத் துணைக்கோடல்",
#                         "english": "Gaining great men's help",
#                         "kurals": []
#                     },
#                     {
#                         "tamil": "சிற்றினஞ் சேராமை",
#                         "english": "Avoiding mean company",
#                         "kurals": []
#                     },
#                     {
#                         "tamil": "தெரிந்து செயல்வகை",
#                         "english": "Deliberation before action",
#                         "kurals": []
#                     },
#                     {
#                         "tamil": "வலியறிதல்",
#                         "english": "Judging strength",
#                         "kurals": []
#                     },
#                     {
#                         "tamil": "காலம் அறிதல்",
#                         "english": "Knowing proper time",
#                         "kurals": []
#                     },
#                     {
#                         "tamil": "இடன் அறிதல்",
#                         "english": "Judging the place",
#                         "kurals": []
#                     },
#                     {
#                         "tamil": "தெரிந்து தெளிதல்",
#                         "english": "Testing of men for confidence",
#                         "kurals": []
#                     },
#                     {
#                         "tamil": "தெரிந்து வினையாடல்",
#                         "english": "Testing and entrusting",
#                         "kurals": []
#                     },
#                     {
#                         "tamil": "சுற்றந்தழால்",
#                         "english": "Cherishing kinsmen",
#                         "kurals": []
#                     },
#                     {
#                         "tamil": "பொச்சாவாமை",
#                         "english": "Unforgetfulness",
#                         "kurals": []
#                     },
#                     {
#                         "tamil": "செங்கோன்மை",
#                         "english": "Just government",
#                         "kurals": []
#                     },
#                     {
#                         "tamil": "கொடுங்கோன்மை",
#                         "english": "The cruel tyranny",
#                         "kurals": []
#                     },
#                     {
#                         "tamil": "வெருவந்த செய்யாமை",
#                         "english": "Avoiding terrorism",
#                         "kurals": []
#                     },
#                     {
#                         "tamil": "கண்ணோட்டம்",
#                         "english": "Benign looks",
#                         "kurals": []
#                     },
#                     {
#                         "tamil": "ஒற்றாடல்",
#                         "english": "Espionage",
#                         "kurals": []
#                     },
#                     {
#                         "tamil": "ஊக்கம் உடைமை",
#                         "english": "Energy",
#                         "kurals": []
#                     },
#                     {
#                         "tamil": "மடியின்மை",
#                         "english": "Freedom from sloth",
#                         "kurals": []
#                     },
#                     {
#                         "tamil": "; ஆள்வினை உடைமை",
#                         "english": "Manly effort",
#                         "kurals": []
#                     },
#                     {
#                         "tamil": "இடுக்கண் அழியாமை",
#                         "english": "Hope in mishap",
#                         "kurals": []
#                     }
#                 ]
#             },
#             {
#                 "tamil": "அமைச்சியல்",
#                 "english": "STATE CABINET",
#                 "category": [
#                     {
#                         "tamil": "அமைச்சு",
#                         "english": "Ministers",
#                         "kurals": []
#                     },
#                     {
#                         "tamil": "சொல்வன்மை",
#                         "english": "Power of speech",
#                         "kurals": []
#                     },
#                     {
#                         "tamil": "வினைத்தூய்மை",
#                         "english": "Purity of action",
#                         "kurals": []
#                     },
#                     {
#                         "tamil": "வினைத்திடபம்",
#                         "english": "Powerful acts",
#                         "kurals": []
#                     },
#                     {
#                         "tamil": "வினைசெயல்வகை",
#                         "english": "Modes of action",
#                         "kurals": []
#                     },
#                     {
#                         "tamil": "தூது",
#                         "english": "The embassy",
#                         "kurals": []
#                     },
#                     {
#                         "tamil": "மன்னரைச் சேர்ந்தொழுகல்",
#                         "english": "Walk with kings",
#                         "kurals": []
#                     },
#                     {
#                         "tamil": "குறிப்பறிதல்",
#                         "english": "Divining the mind",
#                         "kurals": []
#                     },
#                     {
#                         "tamil": "அவை அறிதல்",
#                         "english": "Judging the audience",
#                         "kurals": []
#                     },
#                     {
#                         "tamil": "அவை அஞ்சாமை",
#                         "english": "Courage before councils",
#                         "kurals": []
#                     }
#                 ]
#             },
#             {
#                 "tamil": "அரணியல், கூழியல், படையியல்",
#                 "english": "POLITICS",
#                 "category": [
#                     {
#                         "tamil": "நாடு",
#                         "english": "The country",
#                         "kurals": []
#                     },
#                     {
#                         "tamil": "அரண்",
#                         "english": "Fortress",
#                         "kurals": []
#                     },
#                     {
#                         "tamil": "பொருள் செயல்வகை",
#                         "english": "Way of making wealth",
#                         "kurals": []
#                     },
#                     {
#                         "tamil": "படையாட்சி",
#                         "english": "The glory of army",
#                         "kurals": []
#                     },
#                     {
#                         "tamil": "படைச்செருக்கு",
#                         "english": "Military pride",
#                         "kurals": []
#                     }
#                 ]
#             },
#             {
#                 "tamil": "நட்பியல்",
#                 "english": "ALLIANCE",
#                 "category": [
#                     {
#                         "tamil": "நட்பு",
#                         "english": "Friendship",
#                         "kurals": []
#                     },
#                     {
#                         "tamil": "நட்பாராய்தல்",
#                         "english": "Testing friendship",
#                         "kurals": []
#                     },
#                     {
#                         "tamil": "பழைமை",
#                         "english": "Intimacy",
#                         "kurals": []
#                     },
#                     {
#                         "tamil": "தீநட்பு",
#                         "english": "Bad friendship",
#                         "kurals": []
#                     },
#                     {
#                         "tamil": "கூடாநட்பு",
#                         "english": "False friendship",
#                         "kurals": []
#                     },
#                     {
#                         "tamil": "பேதமை",
#                         "english": "Folly",
#                         "kurals": []
#                     },
#                     {
#                         "tamil": "புலலறிவான்மை",
#                         "english": "Petty conceit",
#                         "kurals": []
#                     },
#                     {
#                         "tamil": "இகல்",
#                         "english": "Hatred",
#                         "kurals": []
#                     },
#                     {
#                         "tamil": "பகைமாட்சி",
#                         "english": "Noble hostility",
#                         "kurals": []
#                     },
#                     {
#                         "tamil": "பகைத்திறம் தெரிதல்",
#                         "english": "Apparising enemies",
#                         "kurals": []
#                     },
#                     {
#                         "tamil": "உட்பகை",
#                         "english": "Secret foe",
#                         "kurals": []
#                     },
#                     {
#                         "tamil": "பெரியாரைப்பிழையாமை",
#                         "english": "Offend not the great",
#                         "kurals": []
#                     },
#                     {
#                         "tamil": "பெண்வழிச்சேறல்",
#                         "english": "Being led by women",
#                         "kurals": []
#                     },
#                     {
#                         "tamil": "வரைவின் மகளிர்",
#                         "english": "Wanton women",
#                         "kurals": []
#                     },
#                     {
#                         "tamil": "கள்ளுண்ணாமை",
#                         "english": "Not drinking liquor",
#                         "kurals": []
#                     },
#                     {
#                         "tamil": "சூது",
#                         "english": "Gambling",
#                         "kurals": []
#                     },
#                     {
#                         "tamil": "மருந்து",
#                         "english": "Medicine",
#                         "kurals": []
#                     }
#                 ]
#             },
#             {
#                 "tamil": "ஒழிபியல்",
#                 "english": "MISCELLANEOUS",
#                 "category": [
#                     {
#                         "tamil": "மானம்",
#                         "english": "Honour",
#                         "kurals": []
#                     },
#                     {
#                         "tamil": "பெருமை",
#                         "english": "Greatness",
#                         "kurals": []
#                     },
#                     {
#                         "tamil": "சான்றாண்மை",
#                         "english": "Sublimity",
#                         "kurals": []
#                     },
#                     {
#                         "tamil": "பண்புடைமை",
#                         "english": "Courtesy",
#                         "kurals": []
#                     },
#                     {
#                         "tamil": "நன்றியில் செல்வம்",
#                         "english": "Futile wealth",
#                         "kurals": []
#                     },
#                     {
#                         "tamil": "நாணுடைமை",
#                         "english": "Sensitiveness to shame",
#                         "kurals": []
#                     },
#                     {
#                         "tamil": "குடிசெயல் வகை",
#                         "english": "Promoting family welfare",
#                         "kurals": []
#                     },
#                     {
#                         "tamil": "உழவு",
#                         "english": "Farming",
#                         "kurals": []
#                     },
#                     {
#                         "tamil": "நல்குரவு",
#                         "english": "Poverty",
#                         "kurals": []
#                     },
#                     {
#                         "tamil": "இரவு",
#                         "english": "Asking",
#                         "kurals": []
#                     },
#                     {
#                         "tamil": "இரவச்சம்",
#                         "english": "Dread of beggary",
#                         "kurals": []
#                     },
#                     {
#                         "tamil": "கயமை",
#                         "english": "Meanness",
#                         "kurals": []
#                     }
#                 ]
#             }
#         ]
#     },
#     {
#         "main_topic": {
#             "tamil": "இன்பத்துப்பால்",
#             "english": "NATURE OF LOVE"
#         },
#         "sub_topic": [
#             {
#                 "tamil": ". களவியல்",
#                 "english": "ON SECRET OF MARRIAGE",
#                 "category": [
#                     {
#                         "tamil": "தகையணங்குறுத்தல்",
#                         "english": "Beauty's dart",
#                         "kurals": []
#                     },
#                     {
#                         "tamil": "குறிப்பறிதல்",
#                         "english": "Signs speak the heart",
#                         "kurals": []
#                     },
#                     {
#                         "tamil": "புணர்ச்சி மகிழ்தல்",
#                         "english": "Embrace bliss",
#                         "kurals": []
#                     },
#                     {
#                         "tamil": "நலம் புனைந்துரைத்தல்",
#                         "english": "Beauty extolled",
#                         "kurals": []
#                     },
#                     {
#                         "tamil": "காதற் சிறப்புரைத்தல்",
#                         "english": "Love's excellence",
#                         "kurals": []
#                     },
#                     {
#                         "tamil": "நாணுத் துறவுரைத்தல்",
#                         "english": "Decorum defied",
#                         "kurals": []
#                     },
#                     {
#                         "tamil": "அலர் அறிவுறுத்தல்",
#                         "english": "Public clamour",
#                         "kurals": []
#                     }
#                 ]
#             },
#             {
#                 "tamil": ". கற்பியல்",
#                 "english": "CHASTE WEDDED LOVE",
#                 "category": [
#                     {
#                         "tamil": "பிரிவாற்றாமை",
#                         "english": "Pangs of separation",
#                         "kurals": []
#                     },
#                     {
#                         "tamil": "படர்மெலிந்திரங்கல்",
#                         "english": "Wailing of pining love",
#                         "kurals": []
#                     },
#                     {
#                         "tamil": "கண்விதுப்பழிதல்",
#                         "english": "Wasteful look for wistful love",
#                         "kurals": []
#                     },
#                     {
#                         "tamil": "பசப்புறு பருவரல்",
#                         "english": "Wailing over pallor",
#                         "kurals": []
#                     },
#                     {
#                         "tamil": "தனிப்படர் மிகுதி",
#                         "english": "Pining alone",
#                         "kurals": []
#                     },
#                     {
#                         "tamil": "நினைந்தவர் புலம்பல்",
#                         "english": "Sad memories",
#                         "kurals": []
#                     },
#                     {
#                         "tamil": "கனவுநிலை உரைத்தல்",
#                         "english": "Dream visions",
#                         "kurals": []
#                     },
#                     {
#                         "tamil": "பொழுதுகண்டிரங்கல்",
#                         "english": "Eventide sigh",
#                         "kurals": []
#                     },
#                     {
#                         "tamil": "உறுப்புநலன் அழிதல்",
#                         "english": "Limbs languish",
#                         "kurals": []
#                     },
#                     {
#                         "tamil": "நெஞ்சொடு கிளத்தல்",
#                         "english": "Soliloquy",
#                         "kurals": []
#                     },
#                     {
#                         "tamil": "நிறையழிதல்",
#                         "english": "Reserve lost",
#                         "kurals": []
#                     },
#                     {
#                         "tamil": "அவர்வயின் விதும்பல்",
#                         "english": "Mutual yearning",
#                         "kurals": []
#                     },
#                     {
#                         "tamil": "குறிப்பறிவுறுத்தல்",
#                         "english": "Feeling surmised",
#                         "kurals": []
#                     },
#                     {
#                         "tamil": "புணர்ச்சி விதும்பல்",
#                         "english": "Longing for reunion",
#                         "kurals": []
#                     },
#                     {
#                         "tamil": "நெஞ்சொடு புலத்தல்",
#                         "english": "Chiding the heart",
#                         "kurals": []
#                     },
#                     {
#                         "tamil": "புலவி",
#                         "english": "Bouderic",
#                         "kurals": []
#                     },
#                     {
#                         "tamil": "புலவி நுணுக்கம்",
#                         "english": "Feigned anger",
#                         "kurals": []
#                     },
#                     {
#                         "tamil": "ஊடலுவகை",
#                         "english": "Sulking charm",
#                         "kurals": []
#                     }
#                 ]
#             }
#         ]
#     }
# ]

# %%
def empty_kural_category():
	for i in range(len(main_topic)):
		for j in range(len(main_topic[i]["sub_topic"])):
			for k in range(len(main_topic[i]["sub_topic"][j]["category"])):
				if len(main_topic[i]["sub_topic"][j]["category"][k]["kurals"]) < 10:
					return i, j, k

	return -1, -1, -1

# %%
first_element = soup.find_next(string=lambda text: text and "------" in text)
kural_id = 0
i, j, k = empty_kural_category()
current_kural = {"tamil": "", "english": ""}
line_count = -1
while first_element and kural_id <= 1330:
	text = clean_text(first_element.get_text())
	first_element = first_element.next_element
	if text:
		if text[0].isdigit():
			line_count = 0
			current_kural = {"tamil": "", "english": ""}

		if line_count > -1:
			if line_count < 2:
				line_count += 1
				current_kural['tamil'] += "\n"
				current_kural['tamil'] += remove_leading_number(text)

			elif line_count >= 2 and line_count <= 6:
				line_count += 1
				current_kural['english'] += "\n"
				current_kural['english'] += remove_leading_number(text)

			if text[-1].isdigit():
				kural_id += 1
				main_topic[i]["sub_topic"][j]["category"][k]["kurals"].append({
					"id": kural_id,
					"tamil": current_kural['tamil'].strip(),
					"english": current_kural['english'].strip()
				})
				current_kural = {"tamil": "", "english": ""}
				line_count = -1
				i, j, k = empty_kural_category()

print(json.dumps(main_topic, indent=4, ensure_ascii=False))
# Out:
# [
#     {
#         "main_topic": {
#             "tamil": "அறத்துப்பால்",
#             "english": "VIRTUE"
#         },
#         "sub_topic": [
#             {
#                 "tamil": "பாயிரம்",
#                 "english": "PREFACE",
#                 "category": [
#                     {
#                         "tamil": "கடவுள் வாழ்த்து",
#                         "english": "The praise of God",
#                         "kurals": [
#                             {
#                                 "id": 1,
#                                 "tamil": "அகர முதல எழுத்தெல்லாம் ஆதி\nபகவன் முதற்றே உலகு",
#                                 "english": "'A' leads letters; the Ancient Lord\nLeads and lords the entire world."
#                             },
#                             {
#                                 "id": 2,
#                                 "tamil": "கற்றதனா லாய பயனென்கொல் வாலறிவன்\nநற்றாள் தொழாஅர் எனின்",
#                                 "english": "That lore is vain which does not fall\nAt His good feet who knoweth all."
#                             },
#                             {
#                                 "id": 3,
#                                 "tamil": "மலர்மிசை ஏகினான் மாணடி சேர்ந்தார்\nநிலமிசை நீடுவாழ் வார்",
#                                 "english": "Long they live on earth who gain\nThe feet of God in florid brain."
#                             },
#                             {
#                                 "id": 4,
#                                 "tamil": "வேண்டுதல் வேண்டாமை இலர்ன்அடி சேர்ந்தார்க்கு\nயாண்டும் இடும்பை இல",
#                                 "english": "Who hold His feet who likes nor loathes\nAre free from woes of human births."
#                             },
#                             {
#                                 "id": 5,
#                                 "tamil": "இருள்சேர் இருவினையும் சேரா இறைவன்\nபொருள்சேர் புகழ்புரிந்தார் மாட்டு",
#                                 "english": "God's praise who tell, are free from right\nAnd wrong, the twins of dreaming night."
#                             },
#                             {
#                                 "id": 6,
#                                 "tamil": "பொறிவாயில் ஐந்தவித்தான் பொய்தீர் ஒழுக்க\nநெறிநின்றார் நீடுவாழ் வார்",
#                                 "english": "They prosper long who walk His way\nWho has the senses signed away."
#                             },
#                             {
#                                 "id": 7,
#                                 "tamil": "தனக்குஉவமை இல்லாதான் தாள்சேர்ந்தார்க்கு கல்லால்\nமனக்கவலை மாற்றல் அரிது",
#                                 "english": "His feet, whose likeness none can find,\nAlone can ease the anxious mind."
#                             },
#                             {
#                                 "id": 8,
#                                 "tamil": "அறவாழி அந்தணன் தாள்சேர்ந்தார்க் கல்லால்\nபிறவாழி நீந்தல் அரிது",
#                                 "english": "Who swims the sea of vice is he\nWho clasps the feet of Virtue's sea."
#                             },
#                             {
#                                 "id": 9,
#                                 "tamil": "கோளில் பொறியில் குணமிலவே எண்குணத்தான்\nதாளை வணங்காத் தலை.",
#                                 "english": "Like senses stale that head is vain\nWhich bows not to Eight-Virtued Divine."
#                             },
#                             {
#                                 "id": 10,
#                                 "tamil": "பிறவிப் பெருங்கடல் நீந்துவர் நீந்தார்\nஇறைவன் அடிசேரா தார்",
#                                 "english": "The sea of births they alone swim\nWho clench His feet and cleave to Him."
#                             }
#                         ]
#                     },
#                     {
#                         "tamil": "வான் சிறப்பு",
#                         "english": "The blessing of Rain",
#                         "kurals": [
#                             {
#                                 "id": 11,
#                                 "tamil": "வான்நின்று உலகம் வழங்கி வருதலால்\nதான்அமிழ்தம் என்றுணரற் பாற்று",
#                                 "english": "The genial rain ambrosia call:\nThe world but lasts while rain shall fall."
#                             },
#                             {
#                                 "id": 12,
#                                 "tamil": "துப்பார்க்குத் துப்பாய துப்பாக்கித் துப்பார்க்குத்\nதுப்பாய தூஉம் மழை",
#                                 "english": "The rain begets the food we eat\nAnd forms a food and drink concrete."
#                             },
#                             {
#                                 "id": 13,
#                                 "tamil": "விண்இன்று பொய்ப்பின் விரிநீர் வியனுலகத்து\nஉள்நின்று உடற்றும் பசி",
#                                 "english": "Let clouds their visits stay, and dearth\nDistresses all the sea-girt earth."
#                             },
#                             {
#                                 "id": 14,
#                                 "tamil": "ஏரின் உழாஅர் உழவர் புயலென்னும்\nவாரி வளங்குன்றிக் கால்",
#                                 "english": "Unless the fruitful shower descend,\nThe ploughman's sacred toil must end."
#                             },
#                             {
#                                 "id": 15,
#                                 "tamil": "கெடுப்பதூஉங் கெட்டார்க்குச் சார்வாய்மற் றாங்கே\nஎடுப்பதூஉம் எல்லாம் மழை",
#                                 "english": "Destruction it may sometimes pour,\nBut only rain can life restore."
#                             },
#                             {
#                                 "id": 16,
#                                 "tamil": "விசும்பின் துளிவீழின் அல்லால்மற் றாங்கே\nபசும்புல் தலைகாண்பு அரிது",
#                                 "english": "No grassy blade its head will rear,\nIf from the cloud no drop appear."
#                             },
#                             {
#                                 "id": 17,
#                                 "tamil": "நெடுங்கடலும் தன்நீர்மை குன்றும் தடிந்தெழிலி\nதான்நல்கா தாகி விடின்",
#                                 "english": "The ocean's wealth will waste away,\nExcept the cloud its stores repay."
#                             },
#                             {
#                                 "id": 18,
#                                 "tamil": "சிறப்பொடு பூசனை செல்லாது வானம்\nவறக்குமேல் வானோர்க்கும் ஈண்டு",
#                                 "english": "The earth, beneath a barren sky,\nWould offerings for the gods deny."
#                             },
#                             {
#                                 "id": 19,
#                                 "tamil": "தானம் தவம்இரண்டும் தங்கா வியன்உலகம்\nவானம் வழங்கா தெனின்.",
#                                 "english": "Were heaven above to fail below\nNor alms nor penance earth would show."
#                             },
#                             {
#                                 "id": 20,
#                                 "tamil": "நீர்இன்று அமையாது உலகெனின் யார்யார்க்கும்\nவான்இன்று அமையாது ஒழுக்கு",
#                                 "english": "Water is life that comes from rain\nSans rain our duties go in vain."
#                             }
#                         ]
#                     },
#                     {
#                         "tamil": "நீத்தார் பெருமை",
#                         "english": "The merit of Ascetics",
#                         "kurals": [
#                             {
#                                 "id": 21,
#                                 "tamil": "ஒழுக்கத்து நீத்தார் பெருமை விழுப்பத்து\nவேண்டும் பனுவல் துணிவு",
#                                 "english": "No merit can be held so high\nAs theirs who sense and self deny."
#                             },
#                             {
#                                 "id": 22,
#                                 "tamil": "துறந்தார் பெருமை துணைக்கூறின் வையத்து\nஇறந்தாரை எண்ணிக்கொண் டற்று",
#                                 "english": "To con ascetic glory here\nIs to count the dead upon the sphere."
#                             },
#                             {
#                                 "id": 23,
#                                 "tamil": "இருமை வகைதெரிந்து ஈண்டுஅறம் பூண்டார்\nபெருமை பிறங்கிற்று உலகு",
#                                 "english": "No lustre can with theirs compare\nWho know the right and virtue wear."
#                             },
#                             {
#                                 "id": 24,
#                                 "tamil": "உரனென்னும் தோட்டியான் ஓரைந்தும் காப்பான்\nவரன்என்னும் வைப்பிற்கோர் வித்து",
#                                 "english": "With hook of firmness to restrain\nThe senses five, is heaven to gain."
#                             },
#                             {
#                                 "id": 25,
#                                 "tamil": "ஐந்தவித்தான் ஆற்றல் அகல்விசும்பு ளார்கோமான்\nஇந்திரனே சாலுங் கரி",
#                                 "english": "Indra himself has cause to say\nHow great the power ascetics' sway."
#                             },
#                             {
#                                 "id": 26,
#                                 "tamil": "செயற்கரிய செய்வார் பெரியர் சிறியர்\nசெயற்கரிய செய்கலா தார்",
#                                 "english": "The small the paths of ease pursue\nThe great achieve things rare to do."
#                             },
#                             {
#                                 "id": 27,
#                                 "tamil": "சுவைஒளி ஊறுஓசை நாற்றமென்று ஐந்தின்\nவகைதெரிவான் கட்டே உலகு",
#                                 "english": "They gain the world, who grasp and tell\nOf taste, sight, hearing, touch and smell."
#                             },
#                             {
#                                 "id": 28,
#                                 "tamil": "நிறைமொழி மாந்தர் பெருமை நிலத்து\nமறைமொழி காட்டி விடும்",
#                                 "english": "Full-worded men by what they say,\nTheir greatness to the world display."
#                             },
#                             {
#                                 "id": 29,
#                                 "tamil": "குணமென்னும் குன்றேறி நின்றார் வெகுளி\nகணமேயுங் காத்தல் அரிது.",
#                                 "english": "Their wrath, who've climb'd the mount of good,\nThough transient, cannot be withstood."
#                             },
#                             {
#                                 "id": 30,
#                                 "tamil": "அந்தணர் என்போர் அறவோர்மற் றெவ்வுயிர்க்கும்\nசெந்தண்மை பூண்டொழுக லான்",
#                                 "english": "With gentle mercy towards all,\nThe sage fulfils the vitue's call."
#                             }
#                         ]
#                     },
#                     {
#                         "tamil": "அறன் வலியுறுத்தல்",
#                         "english": "The power of virtue",
#                         "kurals": [
#                             {
#                                 "id": 31,
#                                 "tamil": "சிறப்புஈனும்; செல்வமும் ஈனும்; அறத்தினுஉங்கு\nஆக்கம் எவனோ உயிர்க்கு",
#                                 "english": "From virtue weal and wealth outflow;\nWhat greater good can mankind know?"
#                             },
#                             {
#                                 "id": 32,
#                                 "tamil": "அறத்தின் ஊங்கு ஆக்கமும் இல்லை; அதனை\nமறத்தலின் ஊங்குஇல்லை கேடு",
#                                 "english": "Virtue enhances joy and gain;\nForsaking it is fall and pain."
#                             },
#                             {
#                                 "id": 33,
#                                 "tamil": "ஒல்லும் வகையான் அறவினை ஓவாதே\nசெல்லும்வா யெல்லாஞ் செயல்",
#                                 "english": "Perform good deeds as much you can\nAlways and everywhere, o man!"
#                             },
#                             {
#                                 "id": 34,
#                                 "tamil": "மனத்துக்கண் மாசிலன் ஆதல்; அனைத்துஅறன்;\nஆகுல நீர பிற",
#                                 "english": "In spotless mind virtue is found\nAnd not in show and swelling sound."
#                             },
#                             {
#                                 "id": 35,
#                                 "tamil": "அழுக்காறு அவாவெகுளி இன்னாச்சொல் நான்கும்\nஇழுக்கா இயன்றது அறம்",
#                                 "english": "Four ills eschew and virtue reach,\nLust, anger, envy, evil-speech."
#                             },
#                             {
#                                 "id": 36,
#                                 "tamil": "அன்றறிவாம் என்னாது அறஞ்செய்க மற்றது\nபொன்றுங்கால் பொன்றாத் துணை",
#                                 "english": "Do good enow; defer it not\nA deathless aid in death if sought."
#                             },
#                             {
#                                 "id": 37,
#                                 "tamil": "அறத்தாறு இதுஎன வேண்டா சிவிகை\nபொறுத்தானோடு ஊர்ந்தான் இடை",
#                                 "english": "Litter-bearer and rider say\nWithout a word, the fortune's way."
#                             },
#                             {
#                                 "id": 38,
#                                 "tamil": "வீழ்நாள் படாஅமை நன்றாற்றின் அஃதொருவன்\nவாழ்நாள் வழியடைக்குங் கல்",
#                                 "english": "Like stones that block rebirth and pain\nAre doing good and good again."
#                             },
#                             {
#                                 "id": 39,
#                                 "tamil": "அறத்தான் வருவதே இன்பம்:மற் றெல்லாம்\nபுறத்த புகழும் இல",
#                                 "english": "Weal flows only from virtue done\nThe rest is rue and renown gone."
#                             },
#                             {
#                                 "id": 40,
#                                 "tamil": "செயற்பால தோரும் அறனே ஒருவற்கு\nஉயற்பால தோரும் பழி.",
#                                 "english": "Worthy act is virtue done\nVice is what we ought to shun."
#                             }
#                         ]
#                     }
#                 ]
#             },
#             {
#                 "tamil": "இல்லறவியல்",
#                 "english": "DOMESTIC VIRTUE",
#                 "category": [
#                     {
#                         "tamil": "இல்வாழ்க்கை",
#                         "english": "Married Life",
#                         "kurals": [
#                             {
#                                 "id": 41,
#                                 "tamil": "இல்வாழ்வான் என்பான் இயல்புடைய மூவர்க்கும்\nநல்லாற்றின் நின்ற துணை",
#                                 "english": "The ideal householder is he\nWho aids the natural orders there."
#                             },
#                             {
#                                 "id": 42,
#                                 "tamil": "துறந்தார்க்கும் துவ்வா தவர்க்கும் இறந்தார்க்கும்\nஇல்வாழ்வான் என்பான் துணை",
#                                 "english": "His help the monk and retired share,\nAnd celebrate students are his care."
#                             },
#                             {
#                                 "id": 43,
#                                 "tamil": "தென்புலத்தார் தெய்வம் விருந்தொக்கல் தானென்றாங்கு\nஐம்புலத்தாறு ஓம்பல் தலை",
#                                 "english": "By dutiful householder's aid\nGod, manes, kin, self and guests are served."
#                             },
#                             {
#                                 "id": 44,
#                                 "tamil": "பழியஞ்சிப் பாத்தூண் உடைத்தாயின் வாழ்க்கை\nவழியெஞ்சல் எஞ்ஞான்றும் இல்",
#                                 "english": "Sin he shuns and food he shares\nHis home is bright and brighter fares."
#                             },
#                             {
#                                 "id": 45,
#                                 "tamil": "அன்பும் அறனும் உடைத்தாயின் இல்வாழ்க்கை\nபண்பும் பயனும் அது",
#                                 "english": "In grace and gain the home excels,\nWhere love with virtue sweetly dwells."
#                             },
#                             {
#                                 "id": 46,
#                                 "tamil": "அறத்தாற்றின் இல்வாழ்க்கை யாற்றின் புறத்தாற்றிற்\nபோஒய்ப் பெறுவது எவன்.",
#                                 "english": "Who turns from righteous family\nTo be a monk, what profits he?"
#                             },
#                             {
#                                 "id": 47,
#                                 "tamil": "இயல்பினான் இல்வாழ்க்கை வாழ்பவன் என்பான்\nமுயல்வாருள் எல்லாம் தலை",
#                                 "english": "Of all who strive for bliss, the great\nIs he who leads the married state."
#                             },
#                             {
#                                 "id": 48,
#                                 "tamil": "ஆற்றின் ஒழுக்கி அறனிழுக்கா இல்வாழ்க்கை\nநோற்பாரின் நோன்மை உடைத்து",
#                                 "english": "Straight in virtue, right in living\nMake men brighter than monks praying."
#                             },
#                             {
#                                 "id": 49,
#                                 "tamil": "அறனெனப் பட்டதே இல்வாழ்க்கை அஃதும்\nபிறன்பழிப்பது இல்லாயின் நன்று",
#                                 "english": "Home-life and virtue, are the same;\nWhich spotless monkhood too can claim."
#                             },
#                             {
#                                 "id": 50,
#                                 "tamil": "வையத்துள் வாழ்வாங்கு வாழ்பவன் வானுறையும்\nதெய்வத்துள் வைக்கப் படும்",
#                                 "english": "He is a man of divine worth\nWho lives in ideal home on earth."
#                             }
#                         ]
#                     },
#                     {
#                         "tamil": "வாழ்க்கைத் துணைநலம்",
#                         "english": "The worth of a wife",
#                         "kurals": [
#                             {
#                                 "id": 51,
#                                 "tamil": "மனைத்தக்க மாண்புடையள் ஆகித்தற் கொண்டான்\nவளத்தக்காள் வாழ்க்கைத் துணை",
#                                 "english": "A good housewife befits the house,\nSpending with thrift the mate's resource."
#                             },
#                             {
#                                 "id": 52,
#                                 "tamil": "மனைமாட்சி இல்லாள்கண் இல்லாயின் வாழ்க்கை\nஎனைமாட்சித் தாயினும் இல்",
#                                 "english": "Bright is home when wife is chaste.\nIf not all greatness is but waste."
#                             },
#                             {
#                                 "id": 53,
#                                 "tamil": "இல்லதென் இல்லவள் மாண்பானால்; உள்ளதென்\nஇல்லவள் மாணாக் கடை",
#                                 "english": "What is rare when wife is good.\nWhat can be there when she is bad?"
#                             },
#                             {
#                                 "id": 54,
#                                 "tamil": "பெண்ணின் பெருந்தக்க யாவுள கற்பென்னும்\nதிண்மையுண் டாகப் பெறின்",
#                                 "english": "What greater fortune is for men\nThan a constant chaste woman?"
#                             },
#                             {
#                                 "id": 55,
#                                 "tamil": "தெய்வந் தொழாஅள் கொழுநன் தொழுதெழுவாள்\nபெய்யெனப் பெய்யும் மழை",
#                                 "english": "Her spouse before God who adores,\nIs like rain that at request pours."
#                             },
#                             {
#                                 "id": 56,
#                                 "tamil": "தற்காத்துத் தற்கொண்டாற் பேணித் தசைசான்ற\nசொற்காத்துச் சோர்விலாள் பெண்",
#                                 "english": "The good wife guards herself from blame,\nShe tends her spouse and brings him fame."
#                             },
#                             {
#                                 "id": 57,
#                                 "tamil": "சிறைகாக்குங் காப்புஎவன் செய்யும் மகளிர்\nநிறைகாக்குங் காப்பே தலை",
#                                 "english": "Of what avail are watch and ward?\nTheir purity is women's guard."
#                             },
#                             {
#                                 "id": 58,
#                                 "tamil": "பெற்றாற் பெறின்பெறுவர் பெண்டிர் பெருஞ்சிறப்புப்\nபுத்தேளிர் வாழும் உலகு",
#                                 "english": "Women who win their husbands' heart\nShall flourish where the gods resort."
#                             },
#                             {
#                                 "id": 59,
#                                 "tamil": "புகழ்புரிந்த இல்லிலோர்க்கு இல்லை இகழ்வவார்முன்\nஏறுபோல் பீடு நடை",
#                                 "english": "A cuckold has not the lion-like gait\nBefore his detractors aright."
#                             },
#                             {
#                                 "id": 60,
#                                 "tamil": "மங்கலம் என்ப மனைமாட்சி மற்றுஅதன்\nநன்கலம் நன்மக்கட் பேறு",
#                                 "english": "An honest wife is home's delight\nAnd children good are jewels abright."
#                             }
#                         ]
#                     },
#                     {
#                         "tamil": "மக்கட்பேறு",
#                         "english": "The wealth of children",
#                         "kurals": [
#                             {
#                                 "id": 61,
#                                 "tamil": "பெறுமவற்றுள் யாமறிவது இல்லை அறிவறிந்த\nமக்கட்பேறு அல்ல பிற",
#                                 "english": "The world no higher bliss bestows\nThan children virtuous and wise."
#                             },
#                             {
#                                 "id": 62,
#                                 "tamil": "எழுபிறப்பும் தீயவை தீண்டா பழிபிறங்காப்\nபண்புடை மக்கட் பெறின்",
#                                 "english": "No evil comes and no blemish;\nNoble sons bring all we wish."
#                             },
#                             {
#                                 "id": 63,
#                                 "tamil": "தம்பொருள் என்பதம் மக்கள் அவர்பொருள்\nதம்தம் வினையான் வரும்",
#                                 "english": "Children are one's wealth indeed\nTheir wealth is measured by their deed."
#                             },
#                             {
#                                 "id": 64,
#                                 "tamil": "அமிர்தினும் ஆற்ற இனிதேதம் மக்கள்\nசிறுகை அளாவிய கூழ்",
#                                 "english": "The food is more than nectar sweet\nIn which one's children hands insert."
#                             },
#                             {
#                                 "id": 65,
#                                 "tamil": "மக்கள்மெய் தீண்டல் உடற்கின்பம் மற்றுஅவர்\nசொற்கேட்டல் இன்பம் செவிக்கு",
#                                 "english": "Children's touch delights the body\nSweet to ears are their words lovely."
#                             },
#                             {
#                                 "id": 66,
#                                 "tamil": "குழல்இனிது யாழ்இனிது என்பதம் மக்கள்\nமழலைச்சொல் கேளா தவர்",
#                                 "english": "The flute and lute are sweet they say\nDeaf to baby's babble's lay!"
#                             },
#                             {
#                                 "id": 67,
#                                 "tamil": "தந்தை மகற்குஆற்றும் நன்றி அவையத்து\nமுந்தி யிருப்பச் செயல்",
#                                 "english": "A father's duty to his son is\nTo seat him in front of the wise."
#                             },
#                             {
#                                 "id": 68,
#                                 "tamil": "தம்மின்தம் மக்கள் அறிவுடமை மாநிலத்து\nமன்னுயிர்க் கெல்லாம் இனிது",
#                                 "english": "With joy the hearts of parents swell\nTo see their children themselves excel."
#                             },
#                             {
#                                 "id": 69,
#                                 "tamil": "ஈன்ற பொழுதிற் பெரிதுவக்கும் தன்மகனைச்\nசான்றோன் எனக்கேட்ட தாய்",
#                                 "english": "The mother, hearing her son's merit\nDelights more than when she begot."
#                             },
#                             {
#                                 "id": 70,
#                                 "tamil": "மகன்தந்தைக்கு ஆற்றும் உதவி இவன்தந்தை\nஎன்னோற்றான் கொல்எனுஞ் சொல்",
#                                 "english": "The son to sire this word is debt\n\"What penance such a son begot!\""
#                             }
#                         ]
#                     },
#                     {
#                         "tamil": "அன்புடைமை",
#                         "english": "Loving-kindness",
#                         "kurals": [
#                             {
#                                 "id": 71,
#                                 "tamil": "அன்பிற்கும் உண்டோ அடைக்குந்தாழ் ஆர்வலர்\nபுன்கண்நீர் பூசல் தரும்",
#                                 "english": "What bolt can bar true love in fact\nThe trickling tears reveal the heart."
#                             },
#                             {
#                                 "id": 72,
#                                 "tamil": "அன்பிலார் எல்லாந் தமக்குரியர்: அன்புடையார்\nஎன்பும் உரியர் பிறர்க்கு",
#                                 "english": "To selves belong the loveless ones;\nTo oth'rs the loving e'en to bones."
#                             },
#                             {
#                                 "id": 73,
#                                 "tamil": "அன்போடு இயைந்த வழக்கென்ப ஆருயிர்க்கு\nஎன்போடு இயைந்த தொடர்பு",
#                                 "english": "Soul is encased in frame of bone\nTo taste the life of love alone."
#                             },
#                             {
#                                 "id": 74,
#                                 "tamil": "அன்புஈனும் ஆர்வம் உடமை: அதுஈனும்\nநண்பென்னும் நாடாச் சிறப்பு",
#                                 "english": "Love yields aspiration and thence\nFriendship springs up in excellence."
#                             },
#                             {
#                                 "id": 75,
#                                 "tamil": "அன்புற்று அமர்ந்த வழக்கென்ப வையகத்து\nஇன்புற்றார் எய்துஞ் சிறப்பு",
#                                 "english": "The crowning joy of home life flows\nFrom peaceful psychic love always."
#                             },
#                             {
#                                 "id": 76,
#                                 "tamil": "அறத்திற்கே அன்புசார்பு யென்ப அறியார்\nமறத்திற்கும் அஃதே துணை",
#                                 "english": "\"Love is virtue's friend\" say know-nots\nIt helps us against evil plots."
#                             },
#                             {
#                                 "id": 77,
#                                 "tamil": "என்பி லதனை வெயில்போலக் காயுமே\nஅன்பிலதனை அறம்",
#                                 "english": "Justice burns the loveless form\nLike solar blaze the boneless worm."
#                             },
#                             {
#                                 "id": 78,
#                                 "tamil": "அன்பகத்தில்லா உயிர்வாழ்க்கை வன்பற்கண்\nவற்றல் மரந்தளிர்த் தற்று",
#                                 "english": "Life bereft of love is gloom\nCan sapless tree in desert bloom?"
#                             },
#                             {
#                                 "id": 79,
#                                 "tamil": "புறத்துறுப் பெல்லாம் எவன்செய்யும் யாக்கை\nஅகத்துறுப்பு அன்பி லவர்க்கு",
#                                 "english": "Love is the heart which limbs must move,\nOr vain the outer parts will prove."
#                             },
#                             {
#                                 "id": 80,
#                                 "tamil": "அன்பின் வழியது உயிர்நிலை அஃதிலார்க்கு\nஎன்புதோல் போர்த்த உடம்பு",
#                                 "english": "The seat of life is love alone;\nOr beings are but skin and bone!"
#                             }
#                         ]
#                     },
#                     {
#                         "tamil": "விருந்தோம்பல்",
#                         "english": "Hospitality",
#                         "kurals": [
#                             {
#                                 "id": 81,
#                                 "tamil": "இருந்தோம்பி இல்வாழ்வ தெல்லாம் விருந்தோம்பி\nவேளாண்மை செய்தற் பொருட்டு",
#                                 "english": "Men set up home, toil and earn\nTo tend the guests and do good turn."
#                             },
#                             {
#                                 "id": 82,
#                                 "tamil": "விருந்து புறத்ததாத் தானுண்டல் சாவா\nமருந்தெனினும் வேண்டற்பாற் றன்று",
#                                 "english": "To keep out guests cannot be good\nAlbeit you eat nectar-like food."
#                             },
#                             {
#                                 "id": 83,
#                                 "tamil": "வருவிருந்து வைகலும் ஓம்புவான் வாழ்க்கை\nபருவந்து பாழ்படுதல் இன்று",
#                                 "english": "Who tends his guests day in and out\nHis life in want never wears out."
#                             },
#                             {
#                                 "id": 84,
#                                 "tamil": "அகனமர்ந்து செய்யாள் உறையும் முகனமர்ந்து\nநல்விருந்து ஓம்புவான் இல்.",
#                                 "english": "The goddess of wealth will gladly rest\nWhere smiles welcome the worthy guest."
#                             },
#                             {
#                                 "id": 85,
#                                 "tamil": "வித்தும் இடல்வேண்டும் கொல்லோ விருந்தோம்பி\nமிச்சில் மிசைவான் புலம்.",
#                                 "english": "Should his field be sown who first\nFeeds the guests and eats the rest?"
#                             },
#                             {
#                                 "id": 86,
#                                 "tamil": "செல்விருந்து ஓம்பி வருவிருந்து பார்த்திருப்பான்\nநல்விருந்து வானத் தவர்க்கு",
#                                 "english": "Who tends a guest and looks for next\nIs a welcome guest in heaven's feast."
#                             },
#                             {
#                                 "id": 87,
#                                 "tamil": "இனைத்துணைத் தென்பதொன் றில்லை: விருந்தின்\nதுணைத்துணை வேள்விப் பயன்",
#                                 "english": "Worth of the guest of quality\nIs worth of hospitality."
#                             },
#                             {
#                                 "id": 88,
#                                 "tamil": "பரிந்தோம்பிப் பற்றற்றேம் என்பர் விருந்தோம்பி\nவேள்வி தலைப்படா தார்",
#                                 "english": "Who loathe guest-service one day cry:\n\"We toil and store; but life is dry\"."
#                             },
#                             {
#                                 "id": 89,
#                                 "tamil": "உடமையுள் இன்மை விருந்தோம்பல் ஓம்பா\nமடமை மடவார்கண் உண்டு",
#                                 "english": "The man of wealth is poor indeed\nWhose folly fails the guest to feed."
#                             },
#                             {
#                                 "id": 90,
#                                 "tamil": "மோப்பக் குழையும் அனிச்சம் முகந்திரிந்து\nநோக்கக் குழையும் விருந்து",
#                                 "english": "Anicham smelt withers: like that\nA wry-faced look withers the guest."
#                             }
#                         ]
#                     },
#                     {
#                         "tamil": ". இனியவை கூறல்",
#                         "english": "Sweet words",
#                         "kurals": [
#                             {
#                                 "id": 91,
#                                 "tamil": "இன்சொலால் ஈரம் அளைஇப் படிறுஇலவாஞ்\nசெம்பொருள் கண்டார்வாய்ச் சொல்",
#                                 "english": "The words of Seers are lovely sweet\nMerciful and free from deceit."
#                             },
#                             {
#                                 "id": 92,
#                                 "tamil": "அகனமர்ந்து ஈதலின் நன்றே முகனமர்ந்து\nஇன்சொல் னாகப் பெறின்",
#                                 "english": "Sweet words from smiling lips dispense\nMore joys than heart's beneficence."
#                             },
#                             {
#                                 "id": 93,
#                                 "tamil": "முகத்தான் அமர்ந்துஇனிது நோக்கி அகத்தானாம்\nஇன்சொ லினதே அறம்",
#                                 "english": "Calm face, sweet look, kind words from heart\nSuch is the gracious virtue's part."
#                             },
#                             {
#                                 "id": 94,
#                                 "tamil": "துன்புறூஉம் துவ்வாமை இல்லாகும் யார்மாட்டும்\nஇன்புறூஉம் இன்சொ லவர்க்கு",
#                                 "english": "Whose loving words delight each one\nThe woe of want from them is gone."
#                             },
#                             {
#                                 "id": 95,
#                                 "tamil": "பணிவுடையன் இன்சொலன் ஆதல் ஒருவற்கு\nஅணியல்ல மற்றுப் பிற",
#                                 "english": "To be humble and sweet words speak\nNo other jewel do wise men seek."
#                             },
#                             {
#                                 "id": 96,
#                                 "tamil": "அல்லவை தேய அறம்பெருகும் நல்லவை\nநாடி இனிய சொலின்",
#                                 "english": "His sins vanish, his virtues grow\nWhose fruitful words with sweetness flow."
#                             },
#                             {
#                                 "id": 97,
#                                 "tamil": "நயன்ஈன்று நன்றி பயக்கும் பயன்ஈன்று\nபண்பின் தலைப்பிரியாச் சொல்",
#                                 "english": "The fruitful courteous kindly words\nLead to goodness and graceful deeds."
#                             },
#                             {
#                                 "id": 98,
#                                 "tamil": "சிறுமையுள் நீங்கிய இன்சொல் மறுமையும்\nஇம்மையும் இன்பந் தரும்",
#                                 "english": "Kind words free from meanness delight\nThis life on earth and life the next."
#                             },
#                             {
#                                 "id": 99,
#                                 "tamil": "இன் சொல் இனிதீன்றல் காண்பான் எவன்கொலோ\nவன்சொல் வழங்கு வது",
#                                 "english": "Who sees the sweets of sweetness here\nTo use harsh words how can he dare?"
#                             },
#                             {
#                                 "id": 100,
#                                 "tamil": "இனிய உளவாக இன்னாத கூறல்\nகனியிருப்பக் காய்கவர்ந் தற்று",
#                                 "english": "Leaving ripe fruits the raw he eats\nWho speaks harsh words when sweet word suits."
#                             }
#                         ]
#                     },
#                     {
#                         "tamil": "செய்ந்நன்றி அறிதல்",
#                         "english": "Gratitude",
#                         "kurals": [
#                             {
#                                 "id": 101,
#                                 "tamil": "செய்யாமற் செய்த உதவிக்கு வையகமும்\nவானகமும் ஆற்ற லரிது",
#                                 "english": "Unhelped in turn good help given\nExceeds in worth earth and heaven."
#                             },
#                             {
#                                 "id": 102,
#                                 "tamil": "காலத்தி னாற்செய்த நன்றி சிறிதெனினும்\nஞாலத்தின் மாணப் பெரிது.",
#                                 "english": "A help rendered in hour of need\nThough small is greater than the world."
#                             },
#                             {
#                                 "id": 103,
#                                 "tamil": "பயன்தூக்கார் செய்த உதவி நயன்தூக்கின்\nநன்மை கடலிற் பெரிது",
#                                 "english": "Help rendered without weighing fruits\nOutweighs the sea in grand effects."
#                             },
#                             {
#                                 "id": 104,
#                                 "tamil": "தினைத்துணை நன்றி செயினும் பனைத்துணையாக்\nகொள்வர் பயன்தெரி வார்.",
#                                 "english": "Help given though millet- small\nKnowers count its good palm- tree tall."
#                             },
#                             {
#                                 "id": 105,
#                                 "tamil": "உதவி வரைத்தன்று உதவி: உதவி\nசெயப்பட்டார் சால்பின் வரைத்து",
#                                 "english": "A help is not the help's measure\nIt is gainer's worth and pleasure."
#                             },
#                             {
#                                 "id": 106,
#                                 "tamil": "மறவற்க மாசற்றார் கேண்மை: துறவற்க\nதுன்பத்துள் துப்பாயார் நட்பு",
#                                 "english": "Forget not friendship of the pure\nForsake not timely helpers sure."
#                             },
#                             {
#                                 "id": 107,
#                                 "tamil": "எழுமை எழுபிறப்பும் உள்ளுவர் தங்கண்\nவிழுமம் துடைத்தவர் நட்பு",
#                                 "english": "Through sevenfold births, in memory fares\nThe willing friend who wiped one's tears."
#                             },
#                             {
#                                 "id": 108,
#                                 "tamil": "நன்றி மறப்பது நன்றன்று: நன்றல்லது\nஅன்றே மறப்பது நன்று.",
#                                 "english": "To forget good turns is not good\nGood it is over wrong not to brood."
#                             },
#                             {
#                                 "id": 109,
#                                 "tamil": "கொன்றன்ன இன்னா செயினும் அவர்செய்த\nஒன்றுநன்று உள்ளக் கெடும்",
#                                 "english": "Let deadly harms be forgotten\nWhile remembering one good-turn."
#                             },
#                             {
#                                 "id": 110,
#                                 "tamil": "எந்நன்றி கொன்றார்க்கும் உய்வுண்டாம்: உய்வில்லை\nசெய்ந்நன்றி கொன்ற மகற்கு",
#                                 "english": "The virtue-killer may be saved\nNot benefit-killer who is damned."
#                             }
#                         ]
#                     },
#                     {
#                         "tamil": "நடுநிலைமை",
#                         "english": "Equity",
#                         "kurals": [
#                             {
#                                 "id": 111,
#                                 "tamil": "தகுதி எனவொன்று நன்றே பகுதியால்\nபாற்பட்டு ஒழுகப் பெறின்",
#                                 "english": "Equity is supreme virtue\nIt is to give each man his due."
#                             },
#                             {
#                                 "id": 112,
#                                 "tamil": "செப்பம் உடையவன் ஆக்கஞ் சிதைவின்றி\nஎச்சத்திற் கேமாப்பு உடைத்து",
#                                 "english": "Wealth of the man of equity\nGrows and lasts to posterity."
#                             },
#                             {
#                                 "id": 113,
#                                 "tamil": "நன்றே தரினும் நடுவிகந்தாம் ஆக்கத்தை\nஅன்றே ஒழிய விடல்",
#                                 "english": "Though profitable, turn away\nFrom unjust gains without delay."
#                             },
#                             {
#                                 "id": 114,
#                                 "tamil": "தக்கார் தகவிலர் என்பது அவரவர்\nஎச்சத்தாற் காணப் படும்",
#                                 "english": "The worthy and the unworthy\nAre seen in their posterity."
#                             },
#                             {
#                                 "id": 115,
#                                 "tamil": "கேடும் பெருக்கமும் இல்லல்ல நெஞ்சத்துக்\nகோடாமை சான்றோர்க் கணி",
#                                 "english": "Loss and gain by cause arise;\nEqual mind adorns the wise."
#                             },
#                             {
#                                 "id": 116,
#                                 "tamil": "கெடுவல்யான் என்பது அறிகதன் நெஞ்சம்\nநடுஒரீஇ அல்ல செயின்.",
#                                 "english": "Of perdition let him be sure\nWho leaves justice to sinful lure."
#                             },
#                             {
#                                 "id": 117,
#                                 "tamil": "கெடுவாக வையாது உலகம் நடுவாக\nநன்றிக்கண் தங்கியான் தாழ்வு",
#                                 "english": "The just reduced to poverty\nIs not held down by equity."
#                             },
#                             {
#                                 "id": 118,
#                                 "tamil": "சமன்செய்து சீர்தூக்குங் கோல்போல் அமைந்தொருபால்\nகோடாமை சான்றோர்க் கணி",
#                                 "english": "Like balance holding equal scales\nA well poised mind is jewel of the wise."
#                             },
#                             {
#                                 "id": 119,
#                                 "tamil": "சொற்கோட்டம் இல்லது செப்பம் ஒருதலையா\nஉட்கோட்டம் இன்மை பெறின்",
#                                 "english": "Justice is upright, unbending\nAnd free from crooked word-twisting."
#                             },
#                             {
#                                 "id": 120,
#                                 "tamil": "வாணிகஞ் செய்வார்க்கு வாணிகம் பேணிப்\nபிறவும் தமபோற் செயின்",
#                                 "english": "A trader's trade prospers fairly\nWhen his dealings are neighbourly."
#                             }
#                         ]
#                     },
#                     {
#                         "tamil": "அடக்கமுடைமை",
#                         "english": "Self-control",
#                         "kurals": [
#                             {
#                                 "id": 121,
#                                 "tamil": "அடக்கம் அமரருள் உய்க்கும்: அடங்காமை\nஆரிருள் உய்த்து விடும்",
#                                 "english": "Self-rule leads to realms of gods\nIndulgence leads to gloomy hades."
#                             },
#                             {
#                                 "id": 122,
#                                 "tamil": "காக்க பொருளா அடக்கத்தை ஆக்கம்\nஅதனினூஉங் கில்லை உயிர்க்கு",
#                                 "english": "No gains with self-control measure\nGuard with care this great treasure."
#                             },
#                             {
#                                 "id": 123,
#                                 "tamil": "செறிவறிந்து சீர்மை பயக்கும் அறிவறிந்து\nஆற்றின் அடங்கப் பெறின்",
#                                 "english": "Knowing wisdom who lives controlled\nName and fame seek him untold."
#                             },
#                             {
#                                 "id": 124,
#                                 "tamil": "நிலையில் திரியாது அடங்கியான் தோற்றம்\nமலையினும் மாணப் பெரிது",
#                                 "english": "Firmly fixed in self serene\nThe sage looks grander than mountain."
#                             },
#                             {
#                                 "id": 125,
#                                 "tamil": "எல்லார்க்கும் நன்றாம் பணிதல் அவருள்ளும்\nசெல்வர்க்கே செல்வந் தகைத்து.",
#                                 "english": "Humility is good for all\nTo the rich it adds a wealth special."
#                             },
#                             {
#                                 "id": 126,
#                                 "tamil": "ஒருமையுள் ஆமைபோல் ஐந்தடக்கல் ஆற்றின்\nஎழுமையும் ஏமாப் புடைத்து.",
#                                 "english": "Who senses five like tortoise hold\nTheir joy prolongs to births sevenfold."
#                             },
#                             {
#                                 "id": 127,
#                                 "tamil": "யாகாவா ராயினும் நாகாக்க காவாக்கால்\nசோகாப்பர் சொல்லிழுக்குப் பட்டு",
#                                 "english": "Rein the tongue if nothing else\nOr slips of tongue bring all the woes."
#                             },
#                             {
#                                 "id": 128,
#                                 "tamil": "ஒன்றானும் தீச்சொல் பொருட்பயன் உண்டாயின்\nநன்றாகா தாகி விடும்",
#                                 "english": "Even a single evil word\nWill turn all good results to bad."
#                             },
#                             {
#                                 "id": 129,
#                                 "tamil": "தீயினாற் சுட்டபுண் உள்ளாறும் ஆறாதே\nநாவினாற் சுட்ட வடு",
#                                 "english": "The fire-burnt wounds do find a cure\nTongue-burnt wound rests a running sore."
#                             },
#                             {
#                                 "id": 130,
#                                 "tamil": "கதங்காத்து கற்றடங்கல் ஆற்றுவான் செவ்வி\nஅறம்பார்க்கும் ஆற்றின் நுழைந்து",
#                                 "english": "Virtue seeks and peeps to see\nSelf-controlled savant anger free."
#                             }
#                         ]
#                     },
#                     {
#                         "tamil": "ஒழுக்கமுடைமை",
#                         "english": "Good decorum",
#                         "kurals": [
#                             {
#                                 "id": 131,
#                                 "tamil": "ஒழுக்கம் விழுப்பம் தரலான் ஒழுக்கம்\nஉயிரினும் ஓம்பப் படும்",
#                                 "english": "Decorum does one dignity\nMore than life guard its purity."
#                             },
#                             {
#                                 "id": 132,
#                                 "tamil": "பரிந்தோம்பிக் காக்க ஒழுக்கம் தெரிந்தோம்பித்\nதேரினும் அஃதே துணை",
#                                 "english": "Virtues of conduct all excel;\nThe soul aid should be guarded well."
#                             },
#                             {
#                                 "id": 133,
#                                 "tamil": "ஒழுக்கம் உடமை குடிமை இழுக்கம்\nஇழிந்த பிறப்பாய் விடும்",
#                                 "english": "Good conduct shows good family\nLow manners mark anomaly."
#                             },
#                             {
#                                 "id": 134,
#                                 "tamil": "மறப்பினும் ஒத்துக் கொளலாகும் பார்ப்பான்\nபிறப்பொழுக்கங் குன்றக் கெடும்",
#                                 "english": "Readers recall forgotten lore,\nBut conduct lost returns no more."
#                             },
#                             {
#                                 "id": 135,
#                                 "tamil": "அழுக்கா றுடையான்கண் ஆக்கம்போன்று இல்லை\nஒழுக்க மிலான்கண் உயர்வு",
#                                 "english": "The envious prosper but ill\nThe ill-behaved sinks lower still."
#                             },
#                             {
#                                 "id": 136,
#                                 "tamil": "ஒழுக்கத்தின் ஒல்கார் உரவோர் இழுக்கத்தின்\nஏதம் படுபாக் கறிந்து",
#                                 "english": "The firm from virtue falter not\nThey know the ills of evil thought."
#                             },
#                             {
#                                 "id": 137,
#                                 "tamil": "ஒழுக்கத்தின் எய்துவர் மேன்மை இழுக்கத்தின்\nஎய்துவர் எய்தாப் பழி",
#                                 "english": "Conduct good ennobles man,\nBad conduct entails disgrace mean."
#                             },
#                             {
#                                 "id": 138,
# ...
#                             },
#                             {
#                                 "id": 1284,
#                                 "tamil": "ஊடற்கண் சென்றேன்மன் தோழி அதுமறந்து\nகூடற்கண் சென்றதுஎன் நெஞ்சு.",
#                                 "english": "Huff I would, maid, but I forget;\nAnd leap to embrace him direct."
#                             },
#                             {
#                                 "id": 1285,
#                                 "tamil": "எழுதுங்கால் கோல்காணாக் கண்ணேபோல் கொண்கன்\nபழிகாணேன் கண்ட விடத்து.",
#                                 "english": "When close I see not lord's blemish\nLike eyes that see not painter's brush."
#                             },
#                             {
#                                 "id": 1286,
#                                 "tamil": "காணுங்கால் காணேன் தவறாய காணாக்கால்\nகாணேன் தவறல் லவை.",
#                                 "english": "When he's with me I see not fault\nAnd nought but fault when he is not."
#                             },
#                             {
#                                 "id": 1287,
#                                 "tamil": "உய்த்தல் அறிந்து புனல்பாய் பவரேபோல்\nபொய்த்தல் அறிந்தென் புலந்து.",
#                                 "english": "To leap in stream which carries off\nWhen lord is close to feign a huff."
#                             },
#                             {
#                                 "id": 1288,
#                                 "tamil": "இளித்தக்க இன்னா செயினும் களித்தார்க்குக்\nகள்ளற்றே கள்வநின் மார்பு.",
#                                 "english": "Like wine to addicts that does disgrace\nYour breast, O thief, is for my embrace!"
#                             },
#                             {
#                                 "id": 1289,
#                                 "tamil": "மலரினும் மெல்லிது காமம் சிலர்அதன்\nசெவ்வி தலைப்படு வார்.",
#                                 "english": "Flower-soft is love; a few alone\nKnow its delicacy so fine."
#                             },
#                             {
#                                 "id": 1290,
#                                 "tamil": "கண்ணின் துனித்தே கலங்கினாள் புல்லுதல்\nஎன்னினும் தான்விதுப் புற்று.",
#                                 "english": "She feigned dislike awhile but flew\nFaster for embrace than I do."
#                             }
#                         ]
#                     },
#                     {
#                         "tamil": "புலவி",
#                         "english": "Bouderic",
#                         "kurals": [
#                             {
#                                 "id": 1291,
#                                 "tamil": "அவர்நெஞ்சு அவர்க்காதல் கண்டும் எவன்நெஞ்சே\nநீஎமக்கு ஆகா தது.",
#                                 "english": "You see, his heart is his alone;\nWhy not my heart be all my own?"
#                             },
#                             {
#                                 "id": 1292,
#                                 "tamil": "உறாஅ தவர்கண்ட கண்ணும் அவரைச்\nசெறாஅரெனச் சேறிஎன் நெஞ்சு.",
#                                 "english": "O heart, you see how he slights me\nYet you clasp him as if friendly."
#                             },
#                             {
#                                 "id": 1293,
#                                 "tamil": "கெட்டார்க்கு நட்டார்இல் என்பதோ நெஞ்சேநீ\nபெட்டாங்கு அவர்பின் செலல்.",
#                                 "english": "You follow him at will. Is it\n\"The fallen have no friends\" my heart?"
#                             },
#                             {
#                                 "id": 1294,
#                                 "tamil": "இனிஅன்ன நின்னோடு சூழ்வார்யார் நெஞ்சே\nதுனிசெய்து துவ்வாய்காண் மற்று.",
#                                 "english": "You won't sulk first and then submit\nWho will then consult you, my heart?"
#                             },
#                             {
#                                 "id": 1295,
#                                 "tamil": "பெறாஅமை அஞ்சும் பெறின்பிரிவு அஞ்சும்\nஅறாஅ இடும்பைத்தென் நெஞ்சு.",
#                                 "english": "Frets to gain and fears loss in gain\nO my heart suffers ceaseless pain."
#                             },
#                             {
#                                 "id": 1296,
#                                 "tamil": "தனியே இருந்து நினைத்தக்கால் என்னைத்\nதினிய இருந்ததுஎன் நெஞ்சு.",
#                                 "english": "My itching mind eats me anon\nAs I muse on him all alone."
#                             },
#                             {
#                                 "id": 1297,
#                                 "tamil": "நாணும் மறந்தேன் அவர்மறக் கல்லாஎன்\nமாணா மடநெஞ்சிற் பட்டு.",
#                                 "english": "forget shame but not his thought\nIn mean foolish mind I'm caught."
#                             },
#                             {
#                                 "id": 1298,
#                                 "tamil": "எள்ளின் இளிவாம்என்று எண்ணி அவர்திறம்\nஉள்ளும் உயிர்க்காதல் நெஞ்சு.",
#                                 "english": "My heart living in love of him\nHails his glory ignoring blame."
#                             },
#                             {
#                                 "id": 1299,
#                                 "tamil": "துன்பத்திற்கு யாரே துணையாவார் தாமுடைய\nநெஞ்சம் துணையல் வழி.",
#                                 "english": "Who support a man in grief\nIf lover's heart denies relief?"
#                             },
#                             {
#                                 "id": 1300,
#                                 "tamil": "தஞ்சம் தமரல்லர் ஏதிலார் தாமுடைய\nநெஞ்சம் தமரல் வழி.",
#                                 "english": "Why wonder if strangers disown\nWhen one's own heart is not his own?"
#                             }
#                         ]
#                     },
#                     {
#                         "tamil": "புலவி நுணுக்கம்",
#                         "english": "Feigned anger",
#                         "kurals": [
#                             {
#                                 "id": 1301,
#                                 "tamil": "புல்லா திராஅப் புலத்தை அவர்உறும்\nஅல்லல்நோய் காண்கம் சிறிது.",
#                                 "english": "Feign sulk; embrace him not so that\nWe can see his distress a bit."
#                             },
#                             {
#                                 "id": 1302,
#                                 "tamil": "உப்பமைந் தற்றால் புலவி அதுசிறிது\nமிக்கற்றால் நீள விடல்.",
#                                 "english": "Sulking is the salt of love; but\nToo much of it spoils the taste."
#                             },
#                             {
#                                 "id": 1303,
#                                 "tamil": "அலந்தாரை அல்லல்நோய் செய்தற்றால் தம்மைப்\nபுலந்தாரைப் புல்லா விடல்.",
#                                 "english": "To leave the sulker unembraced\nIs to grieve the one sorely grieved."
#                             },
#                             {
#                                 "id": 1304,
#                                 "tamil": "ஊடி யவரை உணராமை வாடிய\nவள்ளி முதலரிந் தற்று.",
#                                 "english": "To comfort not lady in pout\nIs to cut the fading plant at root."
#                             },
#                             {
#                                 "id": 1305,
#                                 "tamil": "நலத்தகை நல்லவர்க்கு ஏஎர் புலத்தகை\nபூஅன்ன கண்ணா ரகத்து.",
#                                 "english": "Pouting of flower-eyed has\nTo pure good mates a lovely grace."
#                             },
#                             {
#                                 "id": 1306,
#                                 "tamil": "துனியும் புலவியும் இல்லாயின் காமம்\nகனியும் கருக்காயும் அற்று.",
#                                 "english": "Love devoid of frowns and pets\nMisses its ripe and unripe fruits."
#                             },
#                             {
#                                 "id": 1307,
#                                 "tamil": "ஊடலின் உண்டாங்கோர் துன்பம் புணர்வது\nநீடுவது தன்றுகொல் என்று.",
#                                 "english": "\"Will union take place soon or late?\"\nIn lover's pout this leaves a doubt."
#                             },
#                             {
#                                 "id": 1308,
#                                 "tamil": "நோதல் எவன்மற்று நொந்தாரென்று அஃதறியும்\nகாதலர் இல்லா வழி.",
#                                 "english": "What's the good of grieving lament\nWhen concious lover is not present?"
#                             },
#                             {
#                                 "id": 1309,
#                                 "tamil": "நீரும் நிழலது இனிதே புலவியும்\nவீழுநர் கண்ணே இனிது.",
#                                 "english": "Water delights in a shady grove\nAnd sulking in souls of psychic love."
#                             },
#                             {
#                                 "id": 1310,
#                                 "tamil": "ஊடல் உணங்க விடுவாரோடு என்நெஞ்சம்\nகூடுவேம் என்பது அவா.",
#                                 "english": "My heart athirst would still unite\nWith her who me in sulking left!"
#                             }
#                         ]
#                     },
#                     {
#                         "tamil": "ஊடலுவகை",
#                         "english": "Sulking charm",
#                         "kurals": [
#                             {
#                                 "id": 1311,
#                                 "tamil": "பெண்ணியலார் எல்லோரும் கண்ணின் பொதுஉண்பர்\nநண்ணேன் பரந்தநின் மார்பு.",
#                                 "english": "I shrink to clasp you bosom lewd\nTo the gaze of all ladies exposed."
#                             },
#                             {
#                                 "id": 1312,
#                                 "tamil": "ஊடி யிருந்தேமாத் தும்மினார் யாம்தம்மை\nநீடுவாழ் கென்பாக்கு அறிந்து.",
#                                 "english": "He sneezed while we went on sulking\nExpecting me to say \"live long\"."
#                             },
#                             {
#                                 "id": 1313,
#                                 "tamil": "கோட்டுப்பூச் சூடினும் காயும் ஒருத்தியைக்\nகாட்டிய சூடினீர் என்று.",
#                                 "english": "\"For which lady?\" she widely cries\nWhile I adorn myself with flowers."
#                             },
#                             {
#                                 "id": 1314,
#                                 "tamil": "யாரினும் காதலம் என்றேனா ஊடினாள்\nயாரினும் யாரினும் என்று.",
#                                 "english": "\"I love you more than all\" I said\n\"Than whom, than whom?\" she sulked and chid."
#                             },
#                             {
#                                 "id": 1315,
#                                 "tamil": "இம்மைப் பிறப்பில் பிரியலம் என்றேனாக்\nகண்ணிறை நீர்கொண் டனள்.",
#                                 "english": "\"In this life we won't part\" I told\nHer eyes at once with tears were filled."
#                             },
#                             {
#                                 "id": 1316,
#                                 "tamil": "உள்ளினேன் என்றேன்மற்று என்மறந்தீர் என்றென்னைப்\nபுல்லாள் புலத்தக் கனள்.",
#                                 "english": "I said \"I thought of you\". She left\nHer embrace crying \"Oft you forget\"."
#                             },
#                             {
#                                 "id": 1317,
#                                 "tamil": "வழுத்தினாள் தும்மினே னாக அழித்தழுதாள்\nயாருள்ளித் தும்மினீர் என்று.",
#                                 "english": "I sneezed; she blessed; then changed and wept\n\"You sneezed now at which lady's thought?\""
#                             },
#                             {
#                                 "id": 1318,
#                                 "tamil": "தும்முச் செறுப்ப அழுதாள் நுமர்உள்ளல்\nஎம்மை மறைத்திரோ என்று.",
#                                 "english": "I repressed sneeze; she wept crying\n\"Your thoughts from me you are hiding\"."
#                             },
#                             {
#                                 "id": 1319,
#                                 "tamil": "தன்னை உணர்த்தினும் காயும் பிறர்க்குநீர்\nஇந்நீரர் ஆகுதிர் என்று.",
#                                 "english": "I try to coax her and she remarks\n\"Your coaxing others thus this marks\"."
#                             },
#                             {
#                                 "id": 1320,
#                                 "tamil": "",
#                                 "english": ""
#                             },
#                             {
#                                 "id": 1321,
#                                 "tamil": "இல்லை தவறவர்க்கு ஆயினும் ஊடுதல்\nவல்லது அவர்அளிக்கு மாறு.",
#                                 "english": "He is flawless; but I do pout.\nSo that his loving ways show out."
#                             },
#                             {
#                                 "id": 1322,
#                                 "tamil": "ஊடலில் தோன்றும் சிறுதுனி நல்லளி\nவாடினும் பாடு பெறும்.",
#                                 "english": "Fading first, love blooms and outlives\nThe petty pricks that pouting gives."
#                             },
#                             {
#                                 "id": 1323,
#                                 "tamil": "புலத்தலின் புத்தேள்நாடு உண்டோ நிலத்தொடு\nநீரியைந் தன்னா ரகத்து.",
#                                 "english": "Is there a heaven like sulk beneath\nOf hearts that join like water and earth?"
#                             },
#                             {
#                                 "id": 1324,
#                                 "tamil": "புல்லி விடாஅப் புலவியுள் தோன்றுமென்\nஉள்ளம் உடைக்கும் படை.",
#                                 "english": "In long pout after embrace sweet\nA weapon is up to break my heart."
#                             },
#                             {
#                                 "id": 1325,
#                                 "tamil": "தவறில ராயினும் தாம்வீழ்வார் மென்றோள்\nஅகறலி னாங்கொன்று உடைத்து.",
#                                 "english": "Though free form faults, one feels the charms\nOf feigned release from lover's arms."
#                             },
#                             {
#                                 "id": 1326,
#                                 "tamil": "உணலினும் உண்டது அறல்இனிது காமம்\nபுணர்தலின் ஊடல் இனிது.",
#                                 "english": "Sweeter than meal is digestion\nAnd sulk in love than union."
#                             },
#                             {
#                                 "id": 1327,
#                                 "tamil": "ஊடலில் தோற்றவர் வென்றார் அதுமன்னும்\nகூடலில் காணப் படும்.",
#                                 "english": "The yielder wins in lover's pout\nReunited joy brings it out."
#                             },
#                             {
#                                 "id": 1328,
#                                 "tamil": "ஊடிப் பெறுகுவங் கொல்லோ நுதல்வெயர்ப்பக்\nகூடலில் தோன்றிய உப்பு.",
#                                 "english": "Shall not our pouting again give\nThe dew-browed joy of joint love?"
#                             },
#                             {
#                                 "id": 1329,
#                                 "tamil": "ஊடுக மன்னோ ஒளியிழை யாம்இரப்ப\nநீடுக மன்னோ இரா.",
#                                 "english": "Sulk on O belle of shining jewels!\nProlong O night! our delight swells!"
#                             },
#                             {
#                                 "id": 1330,
#                                 "tamil": "ஊடுதல் காமத்திற்கு இன்பம் அதற்கின்பம்\nகூடி முயங்கப் பெறின்.",
#                                 "english": "Bouderie is lovers' delight\nIts delight grows when they unite"
#                             }
#                         ]
#                     }
#                 ]
#             }
#         ]
#     }
# ]

# %%
converted_kurals = []

def load_data():
	try:
		if os.path.exists("thirukural.json"):
			with open("thirukural.json", "r", encoding="utf-8") as file:
				converted_kurals = json.load(file)
				return converted_kurals
	except:
		pass

	return []

# %%
converted_kurals = load_data()
if len(converted_kurals) == 0:
	for main_topic_obj in main_topic:
		main_topic_tamil = main_topic_obj["main_topic"]["tamil"]
		main_topic_english = main_topic_obj["main_topic"]["english"]
		
		# Process each sub_topic
		for sub_topic in main_topic_obj["sub_topic"]:
			sub_topic_tamil = sub_topic["tamil"]
			sub_topic_english = sub_topic["english"]
			
			# Process each category in the sub_topic
			for category in sub_topic["category"]:
				category_tamil = category["tamil"]
				category_english = category["english"]
				
				# Process each kural in the category
				for kural in category["kurals"]:
					# Create a new kural object in the desired format
					converted_kural = {
						"id": kural["id"],
						"kural_in_tamil": kural["tamil"],
						"kural_in_english": kural["english"],
						"category_in_tamil": category_tamil,
						"category_in_english": category_english,
						"sub_topic_in_tamil": sub_topic_tamil,
						"sub_topic_in_english": sub_topic_english,
						"main_topic_in_tamil": main_topic_tamil,
						"main_topic_in_english": main_topic_english
					}
					
					# Add the converted kural to our list
					converted_kurals.append(converted_kural)

	print(converted_kurals)

# %%
def save_json():
	with open("thirukural.json", "w", encoding="utf-8") as file:
		json.dump(converted_kurals, file, indent=4, ensure_ascii=False)

	print("File saved as thirukural.json")

save_json()
# Out:
# File saved as thirukural.json

# %%
import csv

def convert_tocsv():
	with open("thirukural.csv", 'w', newline='', encoding='utf-8') as file:
		writer = csv.DictWriter(file, fieldnames=converted_kurals[0].keys())
		writer.writeheader()
		writer.writerows(converted_kurals)

	print("File saved as thirukural.csv")

convert_tocsv()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[13], line 11
#       7 		writer.writerows(converted_kurals)
#       9 	print("File saved as thirukural.csv")
# ---> 11 convert_tocsv()
#
# Cell In[13], line 7, in convert_tocsv()
#       5 	writer = csv.DictWriter(file, fieldnames=converted_kurals[0].keys())
#       6 	writer.writeheader()
# ----> 7 	writer.writerows(converted_kurals)
#       9 print("File saved as thirukural.csv")
#
# File /usr/lib/python3.10/csv.py:157, in DictWriter.writerows(self, rowdicts)
#     156 def writerows(self, rowdicts):
# --> 157     return self.writer.writerows(map(self._dict_to_list, rowdicts))
#
# File /usr/lib/python3.10/csv.py:149, in DictWriter._dict_to_list(self, rowdict)
#     147     wrong_fields = rowdict.keys() - self.fieldnames
#     148     if wrong_fields:
# --> 149         raise ValueError("dict contains fields not in fieldnames: "
#     150                          + ", ".join([repr(x) for x in wrong_fields]))
#     151 return (rowdict.get(key, self.restval) for key in self.fieldnames)
#
# ValueError: dict contains fields not in fieldnames: 'query10_in_english'

# %%
for i in range(len(tamil_meaning)):
	if not os.path.exists(tamil_meaning[i].split("/")[-1]):
		# !wget -O {tamil_meaning[i].split("/")[-1]} {tamil_meaning[i]}
		file_name = tamil_meaning[i].split("/")[-1]
		with open(file_name, "r", encoding="utf-8") as file:
			html_content = file.read()

		soup = BeautifulSoup(html_content, "html5lib")
		with open(file_name, "w", encoding="utf-8") as file:
			file.write(soup.prettify())

# %%
def clean_explanation_string(text):
	text = re.sub(r"^[\(\)\[\]-]+|[\(\)\[\]-]+$", "", text).strip()
	text = re.sub(r"^[\(\)\[\]-]+|[\(\)\[\]-]+$", "", text).strip()
	return re.sub(r"^[\(\)\[\]-]+|[\(\)\[\]-]+$", "", text).strip()

# %%
def get_startinng_number(text):
	import re

	# Extract number only if it appears at the start
	match = re.match(r'^\d+', text)

	# Convert to integer if a match is found
	number = int(match.group()) if match else None

	return number

def remove_first_n_words(text, n):
    words = text.split()  # Split text into words
    return ' '.join(words[n:])  # Join after skipping first n words

# %%
totalid = 0
for i in range(len(tamil_meaning)):
	file_name = tamil_meaning[i].split("/")[-1]
	with open(file_name, "r", encoding="utf-8") as file:
		html_content = file.read()

	soup = BeautifulSoup(html_content, "html5lib")
	for row in soup.find_all("tr"):
		if totalid >= len(converted_kurals):
			break

		row_text = remove_leading_number(row.get_text())
		if "விளக்கம்" in row_text:
			row_text = clean_explanation_string(row_text.split("விளக்கம்")[-1])
		else:
			row_text = clean_explanation_string(remove_first_n_words(row_text, 7))

		if row_text:
			index = get_startinng_number(clean_text(row.get_text())) - 1
			converted_kurals[index]["explanation_in_tamil"] = row_text
			totalid += 1

save_json()
convert_tocsv()
# Out:
# File saved as thirukural.json
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[18], line 24
#      21 			totalid += 1
#      23 save_json()
# ---> 24 convert_tocsv()
#
# Cell In[13], line 7, in convert_tocsv()
#       5 	writer = csv.DictWriter(file, fieldnames=converted_kurals[0].keys())
#       6 	writer.writeheader()
# ----> 7 	writer.writerows(converted_kurals)
#       9 print("File saved as thirukural.csv")
#
# File /usr/lib/python3.10/csv.py:157, in DictWriter.writerows(self, rowdicts)
#     156 def writerows(self, rowdicts):
# --> 157     return self.writer.writerows(map(self._dict_to_list, rowdicts))
#
# File /usr/lib/python3.10/csv.py:149, in DictWriter._dict_to_list(self, rowdict)
#     147     wrong_fields = rowdict.keys() - self.fieldnames
#     148     if wrong_fields:
# --> 149         raise ValueError("dict contains fields not in fieldnames: "
#     150                          + ", ".join([repr(x) for x in wrong_fields]))
#     151 return (rowdict.get(key, self.restval) for key in self.fieldnames)
#
# ValueError: dict contains fields not in fieldnames: 'query10_in_english'

# %%
from gemiwrap import GeminiWrapper
from google import genai
import time

converted_kurals = load_data()

system_prompt = """# Tamil to English Explanation Conversion

You are a Tamil-English bilingual assistant. Convert Tamil explanations to clear, culturally appropriate English while:

1. Preserving original meaning and cultural context
2. Explaining Tamil-specific concepts briefly when needed
3. Maintaining the same tone and register as the original
4. Using natural-sounding English rather than literal translations
5. Keeping specialized terminology intact with brief explanations

For culturally-specific terms:
- Retain Tamil words in italics with brief explanations
- Example: "*Kolam* (geometric floor design)"

Prioritize clarity and cultural accuracy over literal translation."""

schema = genai.types.Schema(
			type = genai.types.Type.OBJECT,
			required = ["explanation_in_english"],
			properties = {
				"explanation_in_english": genai.types.Schema(
					type = genai.types.Type.STRING,
				),
			},
		)
gemini = GeminiWrapper(system_instruction=system_prompt, schema=schema)

for i, _ in enumerate(converted_kurals):
	try:
		if "explanation_in_english" not in converted_kurals[i]:
			response = gemini.send_message(converted_kurals[i]["explanation_in_tamil"])
			print(response)
			converted_kurals[i]["explanation_in_english"] = json.loads(response[0])["explanation_in_english"]
			time.sleep(5)
			save_json()
			convert_tocsv()
	except:
		pass
# Out:
# 2025-03-29T18:58:20.367283 system_instruction:: # Tamil to English Explanation Conversion
#
# You are a Tamil-English bilingual assistant. Convert Tamil explanations to clear, culturally appropriate English while:
#
# 1. Preserving original meaning and cultural context
# 2. Explaining Tamil-specific concepts briefly when needed
# 3. Maintaining the same tone and register as the original
# 4. Using natural-sounding English rather than literal translations
# 5. Keeping specialized terminology intact with brief explanations
#
# For culturally-specific terms:
# - Retain Tamil words in italics with brief explanations
# - Example: "*Kolam* (geometric floor design)"
#
# Prioritize clarity and cultural accuracy over literal translation.
# ---------------------------------------------------------------------------------------------------
# 2025-03-29T18:58:20.367425 history:: []
# ---------------------------------------------------------------------------------------------------

# %%
def convertjson_tostr(data_obj):
	str_data = ""
	for key in data_obj.keys():
		str_data += f"{key}: {data_obj[key]}\n"

	return str_data

# %%
converted_kurals = load_data()

system_prompt_question = """You are a specialized assistant for creating LLM training data based on Thirukkural content. For each input containing Thirukkural information, generate 10 different types of queries in both Tamil and English that would logically lead to retrieving this specific Thirukkural as the response.

When processing a Thirukkural input, analyze:
- The couplet text in Tamil and English
- The category and topic classifications
- The explanations and meanings
- Key phrases and concepts

Then create 10 varied query types for each language that someone might use when looking for this specific content, such as:
- Direct quote searches (e.g., "கற்றதனால் ஆய பயன் என்ன?")
- Concept-based queries (e.g., "What does Thirukkural say about knowledge without worship?")
- Category searches (e.g., "Thirukkural on praise of God")
- Topic-specific questions (e.g., "Thirukkural about the value of learning")
- Meaning-based searches (e.g., "Is knowledge without devotion useful according to Thirukkural?")
- Keyword queries (e.g., "Thirukkural knowledge devotion feet")
- Identification queries (e.g., "Which Thirukkural talks about worshipping God's feet?")
- Moral lesson queries (e.g., "Thirukkural teaching about the purpose of knowledge")
- Reference queries (e.g., "Thirukkural from Virtue section about knowledge")
- Application searches (e.g., "How to use knowledge properly according to Thirukkural")

Format your response as:
1. Tamil Queries (numbered 1-10)
2. English Queries (numbered 1-10)

Each query should naturally lead to the specific Thirukkural in the provided input being the appropriate response in a retrieval or Q&A system."""

schema_question = genai.types.Schema(
			type = genai.types.Type.OBJECT,
			required = ["questions_in_tamil", "questions_in_english"],
			properties = {
				"questions_in_tamil": genai.types.Schema(
					type = genai.types.Type.ARRAY,
					items = genai.types.Schema(
						type = genai.types.Type.STRING,
					),
				),
				"questions_in_english": genai.types.Schema(
					type = genai.types.Type.ARRAY,
					items = genai.types.Schema(
						type = genai.types.Type.STRING,
					),
				),
			},
		)

gemini = GeminiWrapper(system_instruction=system_prompt_question, schema=schema_question)

for i, _ in enumerate(converted_kurals):
	if "query0_in_tamil" not in converted_kurals[i]:
		try:
			response = gemini.send_message(convertjson_tostr(converted_kurals[i]))[0]
			for j, question in enumerate(json.loads(response)["questions_in_tamil"]):
				converted_kurals[i][f'query{j}_in_tamil'] = question

			for j, question in enumerate(json.loads(response)["questions_in_english"]):
				converted_kurals[i][f'query{j}_in_english'] = question

			time.sleep(5)
			save_json()
			convert_tocsv()

		except:
			pass
# Out:
# 2025-03-29T18:58:25.212785 system_instruction:: You are a specialized assistant for creating LLM training data based on Thirukkural content. For each input containing Thirukkural information, generate 10 different types of queries in both Tamil and English that would logically lead to retrieving this specific Thirukkural as the response.
#
# When processing a Thirukkural input, analyze:
# - The couplet text in Tamil and English
# - The category and topic classifications
# - The explanations and meanings
# - Key phrases and concepts
#
# Then create 10 varied query types for each language that someone might use when looking for this specific content, such as:
# - Direct quote searches (e.g., "கற்றதனால் ஆய பயன் என்ன?")
# - Concept-based queries (e.g., "What does Thirukkural say about knowledge without worship?")
# - Category searches (e.g., "Thirukkural on praise of God")
# - Topic-specific questions (e.g., "Thirukkural about the value of learning")
# - Meaning-based searches (e.g., "Is knowledge without devotion useful according to Thirukkural?")
# - Keyword queries (e.g., "Thirukkural knowledge devotion feet")
# - Identification queries (e.g., "Which Thirukkural talks about worshipping God's feet?")
# - Moral lesson queries (e.g., "Thirukkural teaching about the purpose of knowledge")
# - Reference queries (e.g., "Thirukkural from Virtue section about knowledge")
# - Application searches (e.g., "How to use knowledge properly according to Thirukkural")
#
# Format your response as:
# 1. Tamil Queries (numbered 1-10)
# 2. English Queries (numbered 1-10)
#
# Each query should naturally lead to the specific Thirukkural in the provided input being the appropriate response in a retrieval or Q&A system.
# ---------------------------------------------------------------------------------------------------
# 2025-03-29T18:58:25.212900 history:: []
# ---------------------------------------------------------------------------------------------------
# 2025-03-29T18:58:25.213680 user_prompt: id: 141
# kural_in_tamil: பிறன்பொருளாள் பெட்டொழுகும் பேதைமை ஞாலத்து
# அறம்பொருள் கண்டார்கண் இல்
# kural_in_english: Who know the wealth and virtue's way
# After other's wife do not stray.
# category_in_tamil: பிறனில் விழையாமை
# category_in_english: Against coveting another's wife
# sub_topic_in_tamil: இல்லறவியல்
# sub_topic_in_english: DOMESTIC VIRTUE
# main_topic_in_tamil: அறத்துப்பால்
# main_topic_in_english: VIRTUE
# explanation_in_tamil: பிறன் பொருள்:பிறன் உடைமை. 'அறம், பொருள்' என்பன ஆகுபெயர். செவ்வெண்ணின் தொகை, விகாரத்தால் தொக்கு நின்றது. இன்பம் ஒன்றையே நோக்கும் இன்ப நூலுடையார் இத்தீயொழுக்கத்தையும் 'பரகீயம்' என்று கூறுவராகலின், 'அறம் பொருள் கண்டார் கண் இல்' என்றார். எனவே, அப் பேதைமை உடையார் மாட்டு அறமும் பொருளும் இல்லை என்பது பெறப்பட்டது.
# explanation_in_english: Another's property: Another's possession. 'Aram', 'Porul' are metonyms. The enumeration of qualities stands elided by transformation. Because those who possess the *Inba* (pleasure) scriptures, which focus only on pleasure, will call this bad conduct 'parageeyam', it said 'not in the eyes of those who have seen virtue and wealth'. Therefore, it is understood that *Aram* (virtue) and *Porul* (wealth) are not present in those who possess that ignorance.
#
# ---------------------------------------------------------------------------------------------------
# 2025-03-29T18:58:26.907290 Quota exceeded, switching API key...
# ---------------------------------------------------------------------------------------------------
# 2025-03-29T18:58:26.972830 system_instruction:: You are a specialized assistant for creating LLM training data based on Thirukkural content. For each input containing Thirukkural information, generate 10 different types of queries in both Tamil and English that would logically lead to retrieving this specific Thirukkural as the response.
#
# When processing a Thirukkural input, analyze:
# - The couplet text in Tamil and English
# - The category and topic classifications
# - The explanations and meanings
# - Key phrases and concepts
#
# Then create 10 varied query types for each language that someone might use when looking for this specific content, such as:
# - Direct quote searches (e.g., "கற்றதனால் ஆய பயன் என்ன?")
# - Concept-based queries (e.g., "What does Thirukkural say about knowledge without worship?")
# - Category searches (e.g., "Thirukkural on praise of God")
# - Topic-specific questions (e.g., "Thirukkural about the value of learning")
# - Meaning-based searches (e.g., "Is knowledge without devotion useful according to Thirukkural?")
# - Keyword queries (e.g., "Thirukkural knowledge devotion feet")
# - Identification queries (e.g., "Which Thirukkural talks about worshipping God's feet?")
# - Moral lesson queries (e.g., "Thirukkural teaching about the purpose of knowledge")
# - Reference queries (e.g., "Thirukkural from Virtue section about knowledge")
# - Application searches (e.g., "How to use knowledge properly according to Thirukkural")
#
# Format your response as:
# 1. Tamil Queries (numbered 1-10)
# 2. English Queries (numbered 1-10)
#
# Each query should naturally lead to the specific Thirukkural in the provided input being the appropriate response in a retrieval or Q&A system.
# ---------------------------------------------------------------------------------------------------
# 2025-03-29T18:58:26.972877 history:: []
# ---------------------------------------------------------------------------------------------------
# 2025-03-29T18:58:26.972887 user_prompt: id: 141
# kural_in_tamil: பிறன்பொருளாள் பெட்டொழுகும் பேதைமை ஞாலத்து
# அறம்பொருள் கண்டார்கண் இல்
# kural_in_english: Who know the wealth and virtue's way
# After other's wife do not stray.
# category_in_tamil: பிறனில் விழையாமை
# category_in_english: Against coveting another's wife
# sub_topic_in_tamil: இல்லறவியல்
# sub_topic_in_english: DOMESTIC VIRTUE
# main_topic_in_tamil: அறத்துப்பால்
# main_topic_in_english: VIRTUE
# explanation_in_tamil: பிறன் பொருள்:பிறன் உடைமை. 'அறம், பொருள்' என்பன ஆகுபெயர். செவ்வெண்ணின் தொகை, விகாரத்தால் தொக்கு நின்றது. இன்பம் ஒன்றையே நோக்கும் இன்ப நூலுடையார் இத்தீயொழுக்கத்தையும் 'பரகீயம்' என்று கூறுவராகலின், 'அறம் பொருள் கண்டார் கண் இல்' என்றார். எனவே, அப் பேதைமை உடையார் மாட்டு அறமும் பொருளும் இல்லை என்பது பெறப்பட்டது.
# explanation_in_english: Another's property: Another's possession. 'Aram', 'Porul' are metonyms. The enumeration of qualities stands elided by transformation. Because those who possess the *Inba* (pleasure) scriptures, which focus only on pleasure, will call this bad conduct 'parageeyam', it said 'not in the eyes of those who have seen virtue and wealth'. Therefore, it is understood that *Aram* (virtue) and *Porul* (wealth) are not present in those who possess that ignorance.
#
# ---------------------------------------------------------------------------------------------------
# 2025-03-29T18:58:28.708437 Quota exceeded, switching API key...
# ---------------------------------------------------------------------------------------------------
# 2025-03-29T18:58:28.772248 system_instruction:: You are a specialized assistant for creating LLM training data based on Thirukkural content. For each input containing Thirukkural information, generate 10 different types of queries in both Tamil and English that would logically lead to retrieving this specific Thirukkural as the response.
#
# When processing a Thirukkural input, analyze:
# - The couplet text in Tamil and English
# - The category and topic classifications
# - The explanations and meanings
# - Key phrases and concepts
#
# Then create 10 varied query types for each language that someone might use when looking for this specific content, such as:
# - Direct quote searches (e.g., "கற்றதனால் ஆய பயன் என்ன?")
# - Concept-based queries (e.g., "What does Thirukkural say about knowledge without worship?")
# - Category searches (e.g., "Thirukkural on praise of God")
# - Topic-specific questions (e.g., "Thirukkural about the value of learning")
# - Meaning-based searches (e.g., "Is knowledge without devotion useful according to Thirukkural?")
# - Keyword queries (e.g., "Thirukkural knowledge devotion feet")
# - Identification queries (e.g., "Which Thirukkural talks about worshipping God's feet?")
# - Moral lesson queries (e.g., "Thirukkural teaching about the purpose of knowledge")
# - Reference queries (e.g., "Thirukkural from Virtue section about knowledge")
# - Application searches (e.g., "How to use knowledge properly according to Thirukkural")
#
# Format your response as:
# 1. Tamil Queries (numbered 1-10)
# 2. English Queries (numbered 1-10)
#
# Each query should naturally lead to the specific Thirukkural in the provided input being the appropriate response in a retrieval or Q&A system.
# ---------------------------------------------------------------------------------------------------
# 2025-03-29T18:58:28.772302 history:: []
# ---------------------------------------------------------------------------------------------------
# 2025-03-29T18:58:28.772312 user_prompt: id: 141
# kural_in_tamil: பிறன்பொருளாள் பெட்டொழுகும் பேதைமை ஞாலத்து
# அறம்பொருள் கண்டார்கண் இல்
# kural_in_english: Who know the wealth and virtue's way
# After other's wife do not stray.
# category_in_tamil: பிறனில் விழையாமை
# category_in_english: Against coveting another's wife
# sub_topic_in_tamil: இல்லறவியல்
# sub_topic_in_english: DOMESTIC VIRTUE
# main_topic_in_tamil: அறத்துப்பால்
# main_topic_in_english: VIRTUE
# explanation_in_tamil: பிறன் பொருள்:பிறன் உடைமை. 'அறம், பொருள்' என்பன ஆகுபெயர். செவ்வெண்ணின் தொகை, விகாரத்தால் தொக்கு நின்றது. இன்பம் ஒன்றையே நோக்கும் இன்ப நூலுடையார் இத்தீயொழுக்கத்தையும் 'பரகீயம்' என்று கூறுவராகலின், 'அறம் பொருள் கண்டார் கண் இல்' என்றார். எனவே, அப் பேதைமை உடையார் மாட்டு அறமும் பொருளும் இல்லை என்பது பெறப்பட்டது.
# explanation_in_english: Another's property: Another's possession. 'Aram', 'Porul' are metonyms. The enumeration of qualities stands elided by transformation. Because those who possess the *Inba* (pleasure) scriptures, which focus only on pleasure, will call this bad conduct 'parageeyam', it said 'not in the eyes of those who have seen virtue and wealth'. Therefore, it is understood that *Aram* (virtue) and *Porul* (wealth) are not present in those who possess that ignorance.
#
# ---------------------------------------------------------------------------------------------------
# 2025-03-29T18:58:30.512459 Quota exceeded, switching API key...
# ---------------------------------------------------------------------------------------------------
# 2025-03-29T18:58:30.578441 system_instruction:: You are a specialized assistant for creating LLM training data based on Thirukkural content. For each input containing Thirukkural information, generate 10 different types of queries in both Tamil and English that would logically lead to retrieving this specific Thirukkural as the response.
#
# When processing a Thirukkural input, analyze:
# - The couplet text in Tamil and English
# - The category and topic classifications
# - The explanations and meanings
# - Key phrases and concepts
#
# Then create 10 varied query types for each language that someone might use when looking for this specific content, such as:
# - Direct quote searches (e.g., "கற்றதனால் ஆய பயன் என்ன?")
# - Concept-based queries (e.g., "What does Thirukkural say about knowledge without worship?")
# - Category searches (e.g., "Thirukkural on praise of God")
# - Topic-specific questions (e.g., "Thirukkural about the value of learning")
# - Meaning-based searches (e.g., "Is knowledge without devotion useful according to Thirukkural?")
# - Keyword queries (e.g., "Thirukkural knowledge devotion feet")
# - Identification queries (e.g., "Which Thirukkural talks about worshipping God's feet?")
# - Moral lesson queries (e.g., "Thirukkural teaching about the purpose of knowledge")
# - Reference queries (e.g., "Thirukkural from Virtue section about knowledge")
# - Application searches (e.g., "How to use knowledge properly according to Thirukkural")
#
# Format your response as:
# 1. Tamil Queries (numbered 1-10)
# 2. English Queries (numbered 1-10)
#
# Each query should naturally lead to the specific Thirukkural in the provided input being the appropriate response in a retrieval or Q&A system.
# ---------------------------------------------------------------------------------------------------
# 2025-03-29T18:58:30.578480 history:: []
# ---------------------------------------------------------------------------------------------------
# 2025-03-29T18:58:30.578488 user_prompt: id: 141
# kural_in_tamil: பிறன்பொருளாள் பெட்டொழுகும் பேதைமை ஞாலத்து
# அறம்பொருள் கண்டார்கண் இல்
# kural_in_english: Who know the wealth and virtue's way
# After other's wife do not stray.
# category_in_tamil: பிறனில் விழையாமை
# category_in_english: Against coveting another's wife
# sub_topic_in_tamil: இல்லறவியல்
# sub_topic_in_english: DOMESTIC VIRTUE
# main_topic_in_tamil: அறத்துப்பால்
# main_topic_in_english: VIRTUE
# explanation_in_tamil: பிறன் பொருள்:பிறன் உடைமை. 'அறம், பொருள்' என்பன ஆகுபெயர். செவ்வெண்ணின் தொகை, விகாரத்தால் தொக்கு நின்றது. இன்பம் ஒன்றையே நோக்கும் இன்ப நூலுடையார் இத்தீயொழுக்கத்தையும் 'பரகீயம்' என்று கூறுவராகலின், 'அறம் பொருள் கண்டார் கண் இல்' என்றார். எனவே, அப் பேதைமை உடையார் மாட்டு அறமும் பொருளும் இல்லை என்பது பெறப்பட்டது.
# explanation_in_english: Another's property: Another's possession. 'Aram', 'Porul' are metonyms. The enumeration of qualities stands elided by transformation. Because those who possess the *Inba* (pleasure) scriptures, which focus only on pleasure, will call this bad conduct 'parageeyam', it said 'not in the eyes of those who have seen virtue and wealth'. Therefore, it is understood that *Aram* (virtue) and *Porul* (wealth) are not present in those who possess that ignorance.
#
# ---------------------------------------------------------------------------------------------------
# 2025-03-29T18:58:32.258846 Quota exceeded, switching API key...
# ---------------------------------------------------------------------------------------------------
# 2025-03-29T18:58:32.324069 system_instruction:: You are a specialized assistant for creating LLM training data based on Thirukkural content. For each input containing Thirukkural information, generate 10 different types of queries in both Tamil and English that would logically lead to retrieving this specific Thirukkural as the response.
#
# When processing a Thirukkural input, analyze:
# - The couplet text in Tamil and English
# - The category and topic classifications
# - The explanations and meanings
# - Key phrases and concepts
#
# Then create 10 varied query types for each language that someone might use when looking for this specific content, such as:
# - Direct quote searches (e.g., "கற்றதனால் ஆய பயன் என்ன?")
# - Concept-based queries (e.g., "What does Thirukkural say about knowledge without worship?")
# - Category searches (e.g., "Thirukkural on praise of God")
# - Topic-specific questions (e.g., "Thirukkural about the value of learning")
# - Meaning-based searches (e.g., "Is knowledge without devotion useful according to Thirukkural?")
# - Keyword queries (e.g., "Thirukkural knowledge devotion feet")
# - Identification queries (e.g., "Which Thirukkural talks about worshipping God's feet?")
# - Moral lesson queries (e.g., "Thirukkural teaching about the purpose of knowledge")
# - Reference queries (e.g., "Thirukkural from Virtue section about knowledge")
# - Application searches (e.g., "How to use knowledge properly according to Thirukkural")
#
# Format your response as:
# 1. Tamil Queries (numbered 1-10)
# 2. English Queries (numbered 1-10)
#
# Each query should naturally lead to the specific Thirukkural in the provided input being the appropriate response in a retrieval or Q&A system.
# ---------------------------------------------------------------------------------------------------
# 2025-03-29T18:58:32.324114 history:: []
# ---------------------------------------------------------------------------------------------------
# 2025-03-29T18:58:32.324123 user_prompt: id: 141
# kural_in_tamil: பிறன்பொருளாள் பெட்டொழுகும் பேதைமை ஞாலத்து
# அறம்பொருள் கண்டார்கண் இல்
# kural_in_english: Who know the wealth and virtue's way
# After other's wife do not stray.
# category_in_tamil: பிறனில் விழையாமை
# category_in_english: Against coveting another's wife
# sub_topic_in_tamil: இல்லறவியல்
# sub_topic_in_english: DOMESTIC VIRTUE
# main_topic_in_tamil: அறத்துப்பால்
# main_topic_in_english: VIRTUE
# explanation_in_tamil: பிறன் பொருள்:பிறன் உடைமை. 'அறம், பொருள்' என்பன ஆகுபெயர். செவ்வெண்ணின் தொகை, விகாரத்தால் தொக்கு நின்றது. இன்பம் ஒன்றையே நோக்கும் இன்ப நூலுடையார் இத்தீயொழுக்கத்தையும் 'பரகீயம்' என்று கூறுவராகலின், 'அறம் பொருள் கண்டார் கண் இல்' என்றார். எனவே, அப் பேதைமை உடையார் மாட்டு அறமும் பொருளும் இல்லை என்பது பெறப்பட்டது.
# explanation_in_english: Another's property: Another's possession. 'Aram', 'Porul' are metonyms. The enumeration of qualities stands elided by transformation. Because those who possess the *Inba* (pleasure) scriptures, which focus only on pleasure, will call this bad conduct 'parageeyam', it said 'not in the eyes of those who have seen virtue and wealth'. Therefore, it is understood that *Aram* (virtue) and *Porul* (wealth) are not present in those who possess that ignorance.
#
# ---------------------------------------------------------------------------------------------------
# 2025-03-29T18:58:34.030377 Quota exceeded, switching API key...
# ---------------------------------------------------------------------------------------------------
# 2025-03-29T18:58:34.097444 system_instruction:: You are a specialized assistant for creating LLM training data based on Thirukkural content. For each input containing Thirukkural information, generate 10 different types of queries in both Tamil and English that would logically lead to retrieving this specific Thirukkural as the response.
#
# When processing a Thirukkural input, analyze:
# - The couplet text in Tamil and English
# - The category and topic classifications
# - The explanations and meanings
# - Key phrases and concepts
#
# Then create 10 varied query types for each language that someone might use when looking for this specific content, such as:
# - Direct quote searches (e.g., "கற்றதனால் ஆய பயன் என்ன?")
# - Concept-based queries (e.g., "What does Thirukkural say about knowledge without worship?")
# - Category searches (e.g., "Thirukkural on praise of God")
# - Topic-specific questions (e.g., "Thirukkural about the value of learning")
# - Meaning-based searches (e.g., "Is knowledge without devotion useful according to Thirukkural?")
# - Keyword queries (e.g., "Thirukkural knowledge devotion feet")
# - Identification queries (e.g., "Which Thirukkural talks about worshipping God's feet?")
# - Moral lesson queries (e.g., "Thirukkural teaching about the purpose of knowledge")
# - Reference queries (e.g., "Thirukkural from Virtue section about knowledge")
# - Application searches (e.g., "How to use knowledge properly according to Thirukkural")
#
# Format your response as:
# 1. Tamil Queries (numbered 1-10)
# 2. English Queries (numbered 1-10)
#
# Each query should naturally lead to the specific Thirukkural in the provided input being the appropriate response in a retrieval or Q&A system.
# ---------------------------------------------------------------------------------------------------
# 2025-03-29T18:58:34.097495 history:: []
# ---------------------------------------------------------------------------------------------------
# 2025-03-29T18:58:34.097504 user_prompt: id: 141
# kural_in_tamil: பிறன்பொருளாள் பெட்டொழுகும் பேதைமை ஞாலத்து
# அறம்பொருள் கண்டார்கண் இல்
# kural_in_english: Who know the wealth and virtue's way
# After other's wife do not stray.
# category_in_tamil: பிறனில் விழையாமை
# category_in_english: Against coveting another's wife
# sub_topic_in_tamil: இல்லறவியல்
# sub_topic_in_english: DOMESTIC VIRTUE
# main_topic_in_tamil: அறத்துப்பால்
# main_topic_in_english: VIRTUE
# explanation_in_tamil: பிறன் பொருள்:பிறன் உடைமை. 'அறம், பொருள்' என்பன ஆகுபெயர். செவ்வெண்ணின் தொகை, விகாரத்தால் தொக்கு நின்றது. இன்பம் ஒன்றையே நோக்கும் இன்ப நூலுடையார் இத்தீயொழுக்கத்தையும் 'பரகீயம்' என்று கூறுவராகலின், 'அறம் பொருள் கண்டார் கண் இல்' என்றார். எனவே, அப் பேதைமை உடையார் மாட்டு அறமும் பொருளும் இல்லை என்பது பெறப்பட்டது.
# explanation_in_english: Another's property: Another's possession. 'Aram', 'Porul' are metonyms. The enumeration of qualities stands elided by transformation. Because those who possess the *Inba* (pleasure) scriptures, which focus only on pleasure, will call this bad conduct 'parageeyam', it said 'not in the eyes of those who have seen virtue and wealth'. Therefore, it is understood that *Aram* (virtue) and *Porul* (wealth) are not present in those who possess that ignorance.
#
# ---------------------------------------------------------------------------------------------------
# 2025-03-29T18:58:35.773630 Quota exceeded, switching API key...
# ---------------------------------------------------------------------------------------------------
# 2025-03-29T18:58:35.836159 system_instruction:: You are a specialized assistant for creating LLM training data based on Thirukkural content. For each input containing Thirukkural information, generate 10 different types of queries in both Tamil and English that would logically lead to retrieving this specific Thirukkural as the response.
#
# When processing a Thirukkural input, analyze:
# - The couplet text in Tamil and English
# - The category and topic classifications
# - The explanations and meanings
# - Key phrases and concepts
#
# Then create 10 varied query types for each language that someone might use when looking for this specific content, such as:
# - Direct quote searches (e.g., "கற்றதனால் ஆய பயன் என்ன?")
# - Concept-based queries (e.g., "What does Thirukkural say about knowledge without worship?")
# - Category searches (e.g., "Thirukkural on praise of God")
# - Topic-specific questions (e.g., "Thirukkural about the value of learning")
# - Meaning-based searches (e.g., "Is knowledge without devotion useful according to Thirukkural?")
# - Keyword queries (e.g., "Thirukkural knowledge devotion feet")
# - Identification queries (e.g., "Which Thirukkural talks about worshipping God's feet?")
# - Moral lesson queries (e.g., "Thirukkural teaching about the purpose of knowledge")
# - Reference queries (e.g., "Thirukkural from Virtue section about knowledge")
# - Application searches (e.g., "How to use knowledge properly according to Thirukkural")
#
# Format your response as:
# 1. Tamil Queries (numbered 1-10)
# 2. English Queries (numbered 1-10)
#
# Each query should naturally lead to the specific Thirukkural in the provided input being the appropriate response in a retrieval or Q&A system.
# ---------------------------------------------------------------------------------------------------
# 2025-03-29T18:58:35.836202 history:: []
# ---------------------------------------------------------------------------------------------------
# 2025-03-29T18:58:35.836213 user_prompt: id: 141
# kural_in_tamil: பிறன்பொருளாள் பெட்டொழுகும் பேதைமை ஞாலத்து
# அறம்பொருள் கண்டார்கண் இல்
# kural_in_english: Who know the wealth and virtue's way
# After other's wife do not stray.
# category_in_tamil: பிறனில் விழையாமை
# category_in_english: Against coveting another's wife
# sub_topic_in_tamil: இல்லறவியல்
# sub_topic_in_english: DOMESTIC VIRTUE
# main_topic_in_tamil: அறத்துப்பால்
# main_topic_in_english: VIRTUE
# explanation_in_tamil: பிறன் பொருள்:பிறன் உடைமை. 'அறம், பொருள்' என்பன ஆகுபெயர். செவ்வெண்ணின் தொகை, விகாரத்தால் தொக்கு நின்றது. இன்பம் ஒன்றையே நோக்கும் இன்ப நூலுடையார் இத்தீயொழுக்கத்தையும் 'பரகீயம்' என்று கூறுவராகலின், 'அறம் பொருள் கண்டார் கண் இல்' என்றார். எனவே, அப் பேதைமை உடையார் மாட்டு அறமும் பொருளும் இல்லை என்பது பெறப்பட்டது.
# explanation_in_english: Another's property: Another's possession. 'Aram', 'Porul' are metonyms. The enumeration of qualities stands elided by transformation. Because those who possess the *Inba* (pleasure) scriptures, which focus only on pleasure, will call this bad conduct 'parageeyam', it said 'not in the eyes of those who have seen virtue and wealth'. Therefore, it is understood that *Aram* (virtue) and *Porul* (wealth) are not present in those who possess that ignorance.
#
# ---------------------------------------------------------------------------------------------------
# 2025-03-29T18:58:37.400060 user_prompt: id: 143
# kural_in_tamil: விளிந்தாரின் வேறல்லர் மன்ற தெளிந்தாரில்
# தீமை புரிந்துஒழுகு வார்
# kural_in_english: The vile are dead who evil aim
# And put faithful friends' wives to shame.
# category_in_tamil: பிறனில் விழையாமை
# category_in_english: Against coveting another's wife
# sub_topic_in_tamil: இல்லறவியல்
# sub_topic_in_english: DOMESTIC VIRTUE
# main_topic_in_tamil: அறத்துப்பால்
# main_topic_in_english: VIRTUE
# explanation_in_tamil: அறம் பொருள் இன்பங்கள் ஆகிய பயன் உயிர் எய்தாமையின், 'விளிந்தாரின் வேறல்லர்' என்றும், அவர் தீமை புரிந்து ஒழுகுவது இல்லுடையவரது தெளிவு பற்றியாகலின், 'தெளிந்தார் இல்' என்றும் கூறினார்.
# explanation_in_english: Because the soul does not attain the benefit of *Aram* (virtue), *Porul* (wealth), and *Inbam* (pleasure), it says 'they are no different from the dead', and because they do evil because of the clarity of the householder, it said 'not in the house of the enlightened'.
#
# ---------------------------------------------------------------------------------------------------
# 2025-03-29T18:58:39.072016 Quota exceeded, switching API key...
# ---------------------------------------------------------------------------------------------------
# 2025-03-29T18:58:39.135431 system_instruction:: You are a specialized assistant for creating LLM training data based on Thirukkural content. For each input containing Thirukkural information, generate 10 different types of queries in both Tamil and English that would logically lead to retrieving this specific Thirukkural as the response.
#
# When processing a Thirukkural input, analyze:
# - The couplet text in Tamil and English
# - The category and topic classifications
# - The explanations and meanings
# - Key phrases and concepts
#
# Then create 10 varied query types for each language that someone might use when looking for this specific content, such as:
# - Direct quote searches (e.g., "கற்றதனால் ஆய பயன் என்ன?")
# - Concept-based queries (e.g., "What does Thirukkural say about knowledge without worship?")
# - Category searches (e.g., "Thirukkural on praise of God")
# - Topic-specific questions (e.g., "Thirukkural about the value of learning")
# - Meaning-based searches (e.g., "Is knowledge without devotion useful according to Thirukkural?")
# - Keyword queries (e.g., "Thirukkural knowledge devotion feet")
# - Identification queries (e.g., "Which Thirukkural talks about worshipping God's feet?")
# - Moral lesson queries (e.g., "Thirukkural teaching about the purpose of knowledge")
# - Reference queries (e.g., "Thirukkural from Virtue section about knowledge")
# - Application searches (e.g., "How to use knowledge properly according to Thirukkural")
#
# Format your response as:
# 1. Tamil Queries (numbered 1-10)
# 2. English Queries (numbered 1-10)
#
# Each query should naturally lead to the specific Thirukkural in the provided input being the appropriate response in a retrieval or Q&A system.
# ---------------------------------------------------------------------------------------------------
# 2025-03-29T18:58:39.135486 history:: []
# ---------------------------------------------------------------------------------------------------
# 2025-03-29T18:58:39.135496 user_prompt: id: 143
# kural_in_tamil: விளிந்தாரின் வேறல்லர் மன்ற தெளிந்தாரில்
# தீமை புரிந்துஒழுகு வார்
# kural_in_english: The vile are dead who evil aim
# And put faithful friends' wives to shame.
# category_in_tamil: பிறனில் விழையாமை
# category_in_english: Against coveting another's wife
# sub_topic_in_tamil: இல்லறவியல்
# sub_topic_in_english: DOMESTIC VIRTUE
# main_topic_in_tamil: அறத்துப்பால்
# main_topic_in_english: VIRTUE
# explanation_in_tamil: அறம் பொருள் இன்பங்கள் ஆகிய பயன் உயிர் எய்தாமையின், 'விளிந்தாரின் வேறல்லர்' என்றும், அவர் தீமை புரிந்து ஒழுகுவது இல்லுடையவரது தெளிவு பற்றியாகலின், 'தெளிந்தார் இல்' என்றும் கூறினார்.
# explanation_in_english: Because the soul does not attain the benefit of *Aram* (virtue), *Porul* (wealth), and *Inbam* (pleasure), it says 'they are no different from the dead', and because they do evil because of the clarity of the householder, it said 'not in the house of the enlightened'.
#
# ---------------------------------------------------------------------------------------------------
# 2025-03-29T18:58:40.775936 Quota exceeded, switching API key...
# ---------------------------------------------------------------------------------------------------
# 2025-03-29T18:58:40.849223 system_instruction:: You are a specialized assistant for creating LLM training data based on Thirukkural content. For each input containing Thirukkural information, generate 10 different types of queries in both Tamil and English that would logically lead to retrieving this specific Thirukkural as the response.
#
# When processing a Thirukkural input, analyze:
# - The couplet text in Tamil and English
# - The category and topic classifications
# - The explanations and meanings
# - Key phrases and concepts
#
# Then create 10 varied query types for each language that someone might use when looking for this specific content, such as:
# - Direct quote searches (e.g., "கற்றதனால் ஆய பயன் என்ன?")
# - Concept-based queries (e.g., "What does Thirukkural say about knowledge without worship?")
# - Category searches (e.g., "Thirukkural on praise of God")
# - Topic-specific questions (e.g., "Thirukkural about the value of learning")
# - Meaning-based searches (e.g., "Is knowledge without devotion useful according to Thirukkural?")
# - Keyword queries (e.g., "Thirukkural knowledge devotion feet")
# - Identification queries (e.g., "Which Thirukkural talks about worshipping God's feet?")
# - Moral lesson queries (e.g., "Thirukkural teaching about the purpose of knowledge")
# - Reference queries (e.g., "Thirukkural from Virtue section about knowledge")
# - Application searches (e.g., "How to use knowledge properly according to Thirukkural")
#
# Format your response as:
# 1. Tamil Queries (numbered 1-10)
# 2. English Queries (numbered 1-10)
#
# Each query should naturally lead to the specific Thirukkural in the provided input being the appropriate response in a retrieval or Q&A system.
# ---------------------------------------------------------------------------------------------------
# 2025-03-29T18:58:40.849267 history:: []
# ---------------------------------------------------------------------------------------------------
# 2025-03-29T18:58:40.849279 user_prompt: id: 143
# kural_in_tamil: விளிந்தாரின் வேறல்லர் மன்ற தெளிந்தாரில்
# தீமை புரிந்துஒழுகு வார்
# kural_in_english: The vile are dead who evil aim
# And put faithful friends' wives to shame.
# category_in_tamil: பிறனில் விழையாமை
# category_in_english: Against coveting another's wife
# sub_topic_in_tamil: இல்லறவியல்
# sub_topic_in_english: DOMESTIC VIRTUE
# main_topic_in_tamil: அறத்துப்பால்
# main_topic_in_english: VIRTUE
# explanation_in_tamil: அறம் பொருள் இன்பங்கள் ஆகிய பயன் உயிர் எய்தாமையின், 'விளிந்தாரின் வேறல்லர்' என்றும், அவர் தீமை புரிந்து ஒழுகுவது இல்லுடையவரது தெளிவு பற்றியாகலின், 'தெளிந்தார் இல்' என்றும் கூறினார்.
# explanation_in_english: Because the soul does not attain the benefit of *Aram* (virtue), *Porul* (wealth), and *Inbam* (pleasure), it says 'they are no different from the dead', and because they do evil because of the clarity of the householder, it said 'not in the house of the enlightened'.
#
# ---------------------------------------------------------------------------------------------------
